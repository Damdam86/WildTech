# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('./dash_app/assets/societes.csv')
df2 = pd.read_csv('entreprises_completes.csv')
df3 = pd.read_csv('merged_df.csv')

# %%
keyword = df3['mots_cles_def']

# %%
keyword
# Out:
# 0        infrastructures du numérique,                 ...
# 1        commission, fintech, insurance, marketplace & ...
# 2                              bc, hosting, semiconductors
# 3        bc, food, home living, in-store retail & resta...
# 4            marketplace & ecommerce, subscription, travel
#                                ...
# 14500                                                  vin
# 14501    blockchain, commission, food, innovative food,...
# 14502        territoires, tech&planet, rse, tech&solutions
# 14503                                              fashion
# 14504    , deep tech, manufacturing, selling own invent...
# Name: mots_cles_def, Length: 14505, dtype: object

# %%
df['mots_cles_def'] = df['mots_cles_def'].fillna('')
# Fusionner les mots-clés de toutes les lignes en une seule grande chaîne
all_keywords = ','.join(df['mots_cles_def'].astype(str))
# Diviser les mots-clés en une liste de mots individuels
keywords_list = [keyword.strip() for keyword in all_keywords.split(',') if keyword.strip()]

# %%
keywords_list
# Out:
# ['infrastructures du numérique',
#  'icc',
#  'iot',
#  'microélectronique',
#  'logiciel',
#  'mesh networks',
#  'commission',
#  'fintech',
#  'insurance',
#  'marketplace & ecommerce',
#  'bc',
#  'hosting',
#  'semiconductors',
#  'bc',
#  'food',
#  'home living',
#  'in-store retail & restaurant tech',
#  'kitchen & cooking tech',
#  'manufacturing',
#  'marketplace & ecommerce',
#  'selling own inventory',
#  'marketplace & ecommerce',
#  'subscription',
#  'travel',
#  'habitat',
#  'home living',
#  'telecommunications',
#  'santé',
#  'e-commerce',
#  'marketplace',
#  'marketplace & ecommerce',
#  'wellness beauty',
#  'telecom',
#  'bretagne',
#  'bb',
#  'fashion',
#  'manufacturing',
#  'selling own inventory',
#  'bb',
#  'bordeaux',
#  'nouvelle-aquitaine',
#  'gironde',
#  'big data',
#  'subscription',
#  'energy',
#  'media',
#  'vente  service client',
#  'software',
#  'bb',
#  'martech adtech salestech',
#  'marketing  communication',
#  'fashion',
#  'manufacturing',
#  'selling own inventory',
#  'home living',
#  'abonnement',
#  'influence',
#  'subscription',
#  'telecom',
#  'bc',
#  'content production',
#  'media',
#  'saas',
#  'subscription',
#  'energie  utilities',
#  'software',
#  'transport  logistique',
#  'subscription',
#  'saas',
#  'transportation',
#  'energy',
#  'clean energy',
#  'mobilité durable',
#  'cloud',
#  'software',
#  'erp',
#  'gpao',
#  'industrie',
#  'production',
#  'service',
#  'jobs recruitment',
#  'selling own inventory',
#  'education',
#  'lifestyle',
#  'content production',
#  'enterprise software',
#  'manufacturing',
#  'media',
#  'saas',
#  'subscription',
#  'education  formation',
#  'industrie',
#  'software',
#  'telecommunications',
#  'media',
#  'streaming',
#  'cybersécurité',
#  'ia',
#  'logiciel',
#  'photonique',
#  'infrastructures du numérique',
#  'île-de-france',
#  'bb',
#  'saas',
#  'rhtech',
#  'ressources humaines',
#  'paris',
#  'île-de-france',
#  'health',
#  'health platform',
#  'mobile app',
#  'saas',
#  'subscription',
#  'proptech',
#  'immobilier',
#  'adtech',
#  'enterprise software',
#  'marketing',
#  'saas',
#  'subscription',
#  'mooc',
#  'communities',
#  'corporate training',
#  'edtech',
#  'education',
#  'subscription',
#  'education',
#  'saas',
#  'mobile app',
#  'learning tools and resources',
#  'education management',
#  'ia  big data',
#  'deeptech',
#  'computer vision',
#  'advertising',
#  'big data',
#  'saas',
#  'subscription',
#  'artificial intelligence',
#  'saas',
#  'jobs recruitment',
#  'enterprise software',
#  'big data',
#  'physique  hardware',
#  'transport  logistique',
#  'd technology',
#  'commission',
#  'deep tech',
#  'education',
#  'manufacturing',
#  'software',
#  'physique  hardware',
#  'loisirs',
#  'music',
#  'deep tech',
#  'manufacturing',
#  'saas',
#  'bc',
#  'd technology',
#  'hardware',
#  'content production',
#  'virtual reality',
#  'media',
#  'd technology',
#  'content production',
#  'media',
#  'subscription',
#  'cybersécurité',
#  'microélectronique',
#  'photonique',
#  'industrie du futur',
#  'newspace',
#  'energie  utilities',
#  'technologie d',
#  'deeptech',
#  'bb',
#  'smart industry',
#  'conception  r&d',
#  'vitry sur seine',
#  'val-de-marne',
#  'île-de-france',
#  'industrie',
#  'transport  logistique',
#  'd',
#  'console & pc gaming',
#  'gaming',
#  'media',
#  'bc',
#  'bb',
#  'auvergne-rhône-alpes',
#  'd printing',
#  'startups',
#  'medical devices',
#  'deep tech',
#  'manufacturing',
#  'health',
#  'd technology',
#  'hardware',
#  'scanner',
#  'focus',
#  'impression',
#  'handyscan',
#  'bb',
#  'numérisation',
#  'proptech',
#  'immobilier',
#  'real estate',
#  'd technology',
#  'commission',
#  'deep tech',
#  'gaming',
#  'iot internetofthings',
#  'manufacturing',
#  'virtual reality',
#  'colomiers',
#  'haute-garonne',
#  'bb',
#  'occitanie',
#  'logistique  opérations',
#  'transport  logistique',
#  'energie  utilities',
#  'deeptech',
#  'deep tech',
#  'energy',
#  'manufacturing',
#  'selling own inventory',
#  'wellness beauty',
#  'fintech',
#  'subscription',
#  'saas',
#  'fintech',
#  'energy',
#  'clean energy',
#  'ressources humaines',
#  'rhtech',
#  'deep tech',
#  'subscription',
#  'energy',
#  'clean energy',
#  'marketing',
#  'subscription',
#  'creation de site',
#  'artificial intelligence',
#  'augmented reality',
#  'big data',
#  'connected device',
#  'enterprise software',
#  'iot internetofthings',
#  'saas',
#  'deep tech',
#  'engineering and manufacturing equipment',
#  'manufacturing',
#  'selling own inventory',
#  'industrie',
#  'software',
#  'transport  logistique',
#  'deep tech',
#  'commission',
#  'artificial intelligence',
#  'saas',
#  'd technology',
#  'hardware',
#  'robotics',
#  'biotechnology',
#  'commission',
#  'health',
#  'manufacturing',
#  'icc',
#  'industrie du futur',
#  'logiciel',
#  'photonique',
#  'telecom',
#  'fin tech',
#  'finance',
#  'bb',
#  'health tech  medtech',
#  'santé',
#  'finance  administration',
#  'health',
#  'biotechnology',
#  'fintech',
#  'commission',
#  'fintech',
#  'wealth management',
#  'jobs recruitment',
#  'mobile app',
#  'saas',
#  'subscription',
#  'bc',
#  'deep tech',
#  'hardware',
#  'manufacturing',
#  'selling own inventory',
#  'sports',
#  'bc',
#  'fintech',
#  'insurance',
#  'marketplace & ecommerce',
#  'saas',
#  'subscription',
#  'wealth management',
#  'accessories',
#  'bc',
#  'commission',
#  'fashion',
#  'luxury',
#  'marketplace & ecommerce',
#  'enterprise software',
#  'marketplace & ecommerce',
#  'saas',
#  'saas',
#  'bb',
#  'vente  service client',
#  'logistique  opérations',
#  'bb',
#  'martech adtech salestech',
#  'marketing  communication',
#  'transport  logistique',
#  'réalité augmentée',
#  'transportation',
#  'travel',
#  'transportation',
#  'subscription',
#  'telecom',
#  'gaming',
#  'mobile gaming',
#  'subscription',
#  'education',
#  'fashion',
#  'home living',
#  'sustainable development goals',
#  'artificial intelligence',
#  'big data',
#  'commission',
#  'fintech',
#  'natural language processing',
#  'saas',
#  'bb',
#  'île-de-france',
#  'catégorie non disponible',
#  'jobs recruitment',
#  'ressources humaines',
#  'rhtech',
#  'console & pc gaming',
#  'gaming',
#  'marketplace & ecommerce',
#  'selling own inventory',
#  'abonnement',
#  'selling own inventory',
#  'marketplace & ecommerce',
#  'home living',
#  'grand est',
#  'bb',
#  'immobilier',
#  'moselle',
#  'marketing',
#  'subscription',
#  'funéraire',
#  'fashion',
#  'commission',
#  'education',
#  'enterprise software',
#  'learning tools and resources',
#  'saas',
#  'commission',
#  'deep tech',
#  'health',
#  'wellness beauty',
#  'industrie',
#  'physique  hardware',
#  'transport  logistique',
#  'accommodation',
#  'booking & search',
#  'commission',
#  'marketplace & ecommerce',
#  'travel',
#  'bb',
#  'finance',
#  'finance  administration',
#  'biométrie',
#  'sécurité',
#  'identité',
#  'stockage',
#  'bc',
#  'auvergne-rhône-alpes',
#  'rhône',
#  'bbc',
#  'santé',
#  'physique  hardware',
#  'health',
#  'biotechnology',
#  'manufacturing',
#  'health',
#  'manufacturing',
#  'e-commerce',
#  'test and measurement',
#  'analytics',
#  'advertising',
#  'ab testing',
#  'subscription',
#  'artificial intelligence',
#  'machine learning',
#  'saas',
#  'marketing',
#  'retail  e-commerce',
#  'service',
#  'tarn',
#  'occitanie',
#  'bb',
#  'marketing  communication',
#  'agritech',
#  'event tech',
#  'food',
#  'biotechnology',
#  'commission',
#  'deep tech',
#  'hardware',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'juridique',
#  'île-de-france',
#  'bb',
#  'legaltech',
#  'comptabilité',
#  'deep tech',
#  'health',
#  'deeptech',
#  'physique  hardware',
#  'bb',
#  'health tech  medtech',
#  'santé',
#  'deep tech',
#  'manufacturing',
#  'selling own inventory',
#  'health',
#  'pharmaceutical',
#  'enterprise software',
#  'saas',
#  'subscription',
#  'commission',
#  'deep tech',
#  'enterprise software',
#  'iot internetofthings',
#  'logistics & delivery',
#  'saas',
#  'transportation',
#  'agritech',
#  'commission',
#  'deep tech',
#  'energy',
#  'food',
#  'saas',
#  'waste solution',
#  'biotechnology',
#  'commission',
#  'health',
#  'manufacturing',
#  'food',
#  'innovative food',
#  'manufacturing',
#  'deep tech',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'selling own inventory',
#  'saas',
#  'software',
#  'artificial intelligence',
#  'deep tech',
#  'health',
#  'machine learning',
#  'medical devices',
#  'saas',
#  'selling own inventory',
#  'biotechnology',
#  'health',
#  'manufacturing',
#  'saas',
#  'biotechnology',
#  'commission',
#  'health',
#  'manufacturing',
#  'pharmaceutical',
#  'telecommunications',
#  'software',
#  'energypower',
#  'enterprise',
#  'imaging',
#  'sourcing and manufacturing',
#  'startups',
#  'health',
#  'biotechnology',
#  'manufacturing',
#  'commission',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'pharmaceutical',
#  'santé',
#  'physique  hardware',
#  'health',
#  'biotechnology',
#  'manufacturing',
#  'commission',
#  'chemicals',
#  'commission',
#  'deep tech',
#  'hardware',
#  'manufacturing',
#  'cloud & infrastructure',
#  'commission',
#  'saas',
#  'security',
#  'artificial intelligence',
#  'deep tech',
#  'food',
#  'machine learning',
#  'recognition technology',
#  'artificial intelligence',
#  'big data',
#  'enterprise software',
#  'machine learning',
#  'saas',
#  'subscription',
#  'home living',
#  'media',
#  'mobile app',
#  'social media',
#  'big data',
#  'commission',
#  'deep tech',
#  'manufacturing',
#  'space',
#  'chimie environnement',
#  'défense',
#  'energie bâtiment',
#  'industrie du futur',
#  'mobilité',
#  'newspace',
#  'logiciel',
#  'microélectronique',
#  'quantique',
#  'blockchain',
#  'crm & sales',
#  'marketing',
#  'saas',
#  'subscription',
#  'environnement',
#  'deep tech',
#  'engineering and manufacturing equipment',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'saas',
#  'subscription',
#  'adtech',
#  'marketing',
#  'saas',
#  'jobs recruitment',
#  'enterprise software',
#  'saas',
#  'subscription',
#  'transportation',
#  'enterprise software',
#  'marketing',
#  'marketing analytics',
#  'saas',
#  'subscription',
#  'energy efficiency',
#  'manufacturing',
#  'commission',
#  'artificial intelligence',
#  'energy',
#  'ressources humaines',
#  'rhtech',
#  'bb',
#  'investissement',
#  'cmos',
#  'île-de-france',
#  'bb',
#  'semiconductor',
#  'wordpress',
#  'telecommunications',
#  'développement web',
#  'php',
#  'création de site internet',
#  'modules personnalisés',
#  'service',
#  'commission',
#  'food',
#  'innovative food',
#  'manufacturing',
#  'achat',
#  'fintech',
#  'insurance',
#  'subscription',
#  'achat',
#  'manufacturing',
#  'payments',
#  'commission',
#  'crypto and defi',
#  'blockchain',
#  'fintech',
#  'telecommunications',
#  'deeptech',
#  'deep tech',
#  'subscription',
#  'telecom',
#  'commission',
#  'deep tech',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'cloud & infrastructure',
#  'saas',
#  'security',
#  'subscription',
#  'enterprise software',
#  'saas',
#  'industrie',
#  'robotique',
#  'bb',
#  'smart industry',
#  'auvergne-rhône-alpes',
#  'intelligence artificielle',
#  'd technology',
#  'biotechnology',
#  'commission',
#  'deep tech',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'logiciel',
#  'microélectronique',
#  'photonique',
#  'non applicable',
#  'hauts-de-france',
#  'bb',
#  'biotechnology',
#  'health',
#  'manufacturing',
#  'santé',
#  'bc',
#  'commission',
#  'marketplace & ecommerce',
#  'robotics',
#  'telecommunications',
#  'data',
#  'iot',
#  'internet of things',
#  'deep tech',
#  'iot internetofthings',
#  'subscription',
#  'telecom',
#  'saas',
#  'enterprise software',
#  'artificial intelligence',
#  'crm & sales',
#  'marketing',
#  'marketing analytics',
#  'saas',
#  'subscription',
#  'software',
#  'transport  logistique',
#  'enterprise software',
#  'saas',
#  'subscription',
#  'commission',
#  'health',
#  'manufacturing',
#  'bourgogne-franche-comté',
#  'bb',
#  'deep tech',
#  'food',
#  'innovative food',
#  'manufacturing',
#  'selling own inventory',
#  'wellness beauty',
#  'biotechnology',
#  'commission',
#  'health',
#  'manufacturing',
#  'environnemental',
#  'catégorie non disponible',
#  'commission',
#  'fintech',
#  'commission',
#  'fintech',
#  'insurance',
#  'big data',
#  'deep tech',
#  'saas',
#  'objets connectés',
#  'logiciel',
#  'hérault',
#  'montpellier',
#  'occitanie',
#  'ia  big data',
#  'bb',
#  'saas',
#  'nanotechnologie',
#  'bbc',
#  'computer vision',
#  'artificial intelligence',
#  'deep tech',
#  'enterprise software',
#  'saas',
#  'subscription',
#  'industrie',
#  'production  maintenance',
#  'deeptech',
#  'physique  hardware',
#  'smart industry',
#  'conception  r&d',
#  'iot  electronique',
#  'deep tech',
#  'manufacturing',
#  'commission',
#  'd technology',
#  'semiconductors',
#  'hardware',
#  'fashion',
#  'manufacturing',
#  'selling own inventory',
#  'ia  big data',
#  'software',
#  'deeptech',
#  'logistique  opérations',
#  'finance  administration',
#  'transport  logistique',
#  'augmented reality',
#  'computer vision',
#  'deep learning',
#  'deep tech',
#  'health',
#  'machine learning',
#  'manufacturing',
#  'medical devices',
#  'selling own inventory',
#  'autonomous & sensor tech',
#  'commission',
#  'deep tech',
#  'hardware',
#  'manufacturing',
#  'robotics',
#  'bc',
#  'commission',
#  'media',
#  'publishing',
#  'recognition technology',
#  'saas',
#  'social media',
#  'subscription',
#  'industrie',
#  'conformité',
#  'certification',
#  'service',
#  'biotechnology',
#  'commission',
#  'health',
#  'health platform',
#  'manufacturing',
#  'video',
#  'advertising platforms',
#  'mobile advertising',
#  'advertising',
#  'vente  service client',
#  'occitanie',
#  'bb',
#  'martech adtech salestech',
#  'marketing  communication',
#  'logistique  opérations',
#  'transport  logistique',
#  'bc',
#  'commission',
#  'education',
#  'education providers',
#  'marketplace & ecommerce',
#  'adtech',
#  'artificial intelligence',
#  'big data',
#  'commission',
#  'deep learning',
#  'machine learning',
#  'marketing',
#  'media',
#  'natural language processing',
#  'energie  utilities',
#  'software',
#  'transport  logistique',
#  'content production',
#  'media',
#  'subscription',
#  'santé',
#  'physique  hardware',
#  'content production',
#  'media',
#  'travel',
#  'content production',
#  'media',
#  'artificial intelligence',
#  'enterprise software',
#  'machine learning',
#  'saas',
#  'd technology',
#  'deep tech',
#  'enterprise software',
#  'manufacturing',
#  'robotics',
#  'saas',
#  'subscription',
#  'nanotechnologie',
#  'loisirs',
#  'adtech',
#  'artificial intelligence',
#  'marketing',
#  'subscription',
#  'biotechnology',
#  'commission',
#  'health',
#  'manufacturing',
#  'mobilité durable',
#  'deep tech',
#  'transportation',
#  'vehicle production',
#  'energy',
#  'deep tech',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'selling own inventory',
#  'commission',
#  'manufacturing',
#  'ia  big data',
#  'bb',
#  'ia  big data',
#  'spacetech',
#  'auvergne-rhône-alpes',
#  'ia  big data',
#  'bb',
#  'nanotechnologie',
#  'computer vision',
#  'application',
#  'assistant personnel',
#  'voyage',
#  'nanotechnologie',
#  'physique  hardware',
#  'catégorie non disponible',
#  'saas',
#  'subscription',
#  'jobs recruitment',
#  'ia  big data',
#  'spacetech',
#  'industrie',
#  'micro-electronique',
#  'recrutement',
#  'commission',
#  'connected device',
#  'deep tech',
#  'hardware',
#  'health',
#  'manufacturing',
#  'medical devices',
#  'tech&planet',
#  'rse',
#  'mobilites',
#  'industrie',
#  'health',
#  'biotechnology',
#  'manufacturing',
#  'selling own inventory',
#  'crm & sales',
#  'marketing',
#  'subscription',
#  'fintech',
#  'legal',
#  'ia  big data',
#  'vente  service client',
#  'software',
#  'bb',
#  'martech adtech salestech',
#  'marketing  communication',
#  'ecommerce solutions',
#  'subscription',
#  'artificial intelligence',
#  'saas',
#  'machine learning',
#  'marketing',
#  'big data',
#  'energie bâtiment',
#  'industrie du futur',
#  'mobilité',
#  'santé',
#  'logiciel',
#  'microélectronique',
#  'photonique',
#  'ia  big data',
#  'bb',
#  'sécurité  défense',
#  'it  digital',
#  'bc',
#  'bb',
#  'loisirs',
#  'gaming',
#  'mobile gaming',
#  'advertising',
#  'users',
#  'adikteev',
#  'performance',
#  'berlin',
#  'information',
#  'francisco',
#  'us',
#  'san',
#  'advertising',
#  'mobile',
#  'fr',
#  'paris',
#  'advertising',
#  'new',
#  'data',
#  'get',
#  'started',
#  'creative',
#  'collect',
#  'advertising platforms',
#  'york',
#  'use',
#  'ad targeting',
#  'crm & sales',
#  'subscription',
#  'artificial intelligence',
#  'machine learning',
#  'saas',
#  'mobile app',
#  'gaming',
#  'marketing',
#  'adtech',
#  'commission',
#  'education',
#  'learning tools and resources',
#  'clean energy',
#  'deep tech',
#  'energy',
#  'hardware',
#  'manufacturing',
#  'water',
#  'biotechnology',
#  'commission',
#  'health',
#  'manufacturing',
#  'pharmaceutical',
#  'telecom',
#  'jobs recruitment',
#  'logiciel',
#  'microélectronique',
#  'photonique',
#  'chimie environnement',
#  'energie bâtiment',
#  'industrie du futur',
#  'mobilité',
#  'newspace',
#  'santé',
#  'ia',
#  'rse',
#  'communication',
#  'cybersecurite',
#  'commission',
#  'fintech',
#  'payments',
#  'jobs recruitment',
#  'vente  service client',
#  'software',
#  'logistique  opérations',
#  'martech adtech salestech',
#  'marketing  communication',
#  'transport  logistique',
#  'biotechnology',
#  'commission',
#  'enterprise software',
#  'health',
#  'marketplace & ecommerce',
#  'pharmaceutical',
#  'saas',
#  'subscription',
#  'marketing',
#  'mobile app',
#  'subscription',
#  'vente  service client',
#  'martech adtech salestech',
#  'marketing  communication',
#  'e-commerce',
#  'marketplace',
#  'marketplace & ecommerce',
#  'subscription',
#  'commission',
#  'marketing',
#  'adtech',
#  'ia',
#  ...]

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# entreprise_id  14335.0  7.168000e+03  4.138302e+03  1.000000e+00
# SIRET           7726.0  7.347448e+13  1.899344e+13  1.831002e+13
# latitude       11920.0  4.668457e+01  6.531463e+00 -4.128880e+01
# longitude      11920.0  3.875585e+00  1.768984e+01 -1.494452e+02
#
#                         25%           50%           75%           max
# entreprise_id  3.584500e+03  7.168000e+03  1.075150e+04  1.433500e+04
# SIRET          5.222110e+13  8.189808e+13  8.802430e+13  9.878324e+13
# latitude       4.573827e+01  4.883194e+01  4.886681e+01  6.149802e+01
# longitude      2.247743e+00  2.320041e+00  4.013311e+00  1.747772e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14335 entries, 0 to 14334
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   entreprise_id        14335 non-null  int64
#  1   nom                  14335 non-null  object
#  2   description          13681 non-null  object
#  3   logo                 14326 non-null  object
#  4   Type d'organisme     6168 non-null   object
#  5   SIREN                11623 non-null  object
#  6   Activité principale  7727 non-null   object
#  7   Effectif_def         7929 non-null   object
#  8   market               6769 non-null   object
#  9   mots_cles_def        14335 non-null  object
#  10  site_web_def         7961 non-null   object
#  11  adresse_def          12386 non-null  object
#  12  date_creation_def    9087 non-null   object
#  13  SIRET                7726 non-null   float64
#  14  Date de fermeture    1151 non-null   object
#  15  latitude             11920 non-null  float64
#  16  longitude            11920 non-null  float64
# dtypes: float64(3), int64(1), object(13)
# memory usage: 1.9+ MB

# %%
find_siren
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 find_siren
#
# NameError: name 'find_siren' is not defined

# %%
df_siren = df[(df['SIREN'] != 'Non disponible') & (~df['SIREN'].isna())]

# %%
df2
# Out:
#       Unnamed: 0                 nom  \
# 0              5  1001-ARCHITECTURES
# 1              7      1001PHARMACIES
# 2              8                100M
# 3              9                1083
# 4             10               10H11
# ...          ...                 ...
# 7738       14330               ZORBA
# 7739       14332               ZOZIO
# 7740       14336               ZYGON
# 7741       14338                 ZYL
# 7742       14339            ZYMOPTIQ
#
#                                             description  \
# 0           1001 Façons de sublimer votre espace de vie
# 1     Achetez sur internet chez les pharmacies franç...
# 2     100M simplifie la production du reporting trad...
# 3                 Manufacture jeans and shoes in France
# 4     10h11 est une société technologique dans l’opt...
# ...                                                 ...
# 7738  Bringing purpose to stories while exploring li...
# 7739  The first digital companion of the industrial ...
# 7740  Comprehensive SaaS security solution offering ...
# 7741  Zyl (anciennement Comet) est une application m...
# 7742  En facilitant la mesure enzymatique, nous rend...
#
#                                                    logo  \
# 0     https://d3kqkuy1hpjocx.cloudfront.net/s3fs-pub...
# 1     https://storage.googleapis.com/dealroom-images...
# 2     https://upload.prd.hbd.cloud.bpifrance.fr/star...
# 3     https://storage.googleapis.com/dealroom-images...
# 4     https://storage.googleapis.com/dealroom-images...
# ...                                                 ...
# 7738  https://storage.googleapis.com/dealroom-images...
# 7739  https://maddyness.twic.pics/2022/05/Capture-de...
# 7740  https://storage.googleapis.com/dealroom-images...
# 7741  https://maddyness.twic.pics/2019/09/Logo-Zyl.p...
# 7742  https://storage.googleapis.com/dealroom-images...
#
#      Date dernier financement     Série LinkedIn Type d'organisme  \
# 0                         NaN       NaN      NaN              NaN
# 1                         NaN       NaN      NaN              NaN
# 2                         NaN       NaN      NaN              NaN
# 3                         NaN       NaN      NaN              NaN
# 4                         NaN       NaN      NaN              NaN
# ...                       ...       ...      ...              ...
# 7738                      NaN       NaN      NaN              NaN
# 7739               2022-01-05  Amorçage      NaN              NaN
# 7740                      NaN       NaN      NaN              NaN
# 7741                      NaN       NaN      NaN              NaN
# 7742                      NaN       NaN      NaN              NaN
#
#      Activité principale market  ...             Commune  \
# 0                    NaN    NaN  ...           GAMBSHEIM
# 1                 64.20Z    B2C  ...               PARIS
# 2                 58.29A    NaN  ...             PARIS 2
# 3                    NaN    B2C  ...    ROMANS-SUR-ISERE
# 4                 58.29C    B2C  ...            BORDEAUX
# ...                  ...    ...  ...                 ...
# 7738                 NaN    B2B  ...  EVRY-COURCOURONNES
# 7739              62.02A    B2B  ...             ALEMBON
# 7740                 NaN    B2B  ...                CAEN
# 7741              14.13Z    NaN  ...            SAMOREAU
# 7742              74.90B    B2B  ...            LEZENNES
#
#                                       Adresse complète Date de création  \
# 0               2b Rue des Marronniers 67760 Gambsheim       2018-08-01
# 1                        128 Rue la Boétie 75008 Paris       2015-06-09
# 2                                                  NaN       2016-09-30
# 3            49 Avenue Gambetta 26100 Romans-sur-Isère       2014-08-27
# 4                       88 Rue Judaïque 33000 Bordeaux       2011-03-07
# ...                                                ...              ...
# 7738  45 Boulevard Decauville 91000 Évry-Courcouronnes       1987-09-21
# 7739                   441 Rue du Ventus 62850 Alembon       2018-11-14
# 7740                                               NaN       2023-07-11
# 7741              48 Voie de la Liberté 77210 Samoreau       2019-10-29
# 7742          Rue Pierre et Marie Curie 59260 Lezennes       2019-01-01
#
#      Date de fermeture Effectif salarié Code NAF Catégorie entreprise  \
# 0                  NaN               01   59.11A                  PME
# 1                  NaN              NaN   64.20Z                  PME
# 2           2019-08-31              NaN   58.29A                  NaN
# 3                  NaN               11   47.71Z                  PME
# 4                  NaN               02   58.29C                  PME
# ...                ...              ...      ...                  ...
# 7738        2021-11-22              NaN   56.10A                  NaN
# 7739               NaN              NaN   62.02A                  PME
# 7740               NaN              NaN   62.01Z                  NaN
# 7741               NaN              NaN   14.13Z                  PME
# 7742               NaN               12   74.90B                  PME
#
#                                     Dirigeant principal Coordonnée Lambert X  \
# 0              MINGOT LUDOVIC ROBERT / PELEGRY STEPHANE            48.695699
# 1     BOULEUC FREDERIC / BOURDEAU DE FONTENAY MIGUEL...            48.870938
# 2                                                   NaN                  NaN
# 3         HURIEZ GREGOIRE CLAUDE / HURIEZ THOMAS CLAUDE            45.045220
# 4                       DAUBERT JULIEN JEAN ROGER /  /             44.841200
# ...                                                 ...                  ...
# 7738                                       IPEK MUSTAFA            48.638029
# 7739                        HERDIER KEVIN JEAN-PHILIPPE            50.799317
# 7740                                                NaN            49.174249
# 7741                     ZYLBERBERG (ZYLBERBERG) ARNAUD            48.429191
# 7742                                     PEBAY PHILIPPE            50.603255
#
#       Coordonnée Lambert Y
# 0                 7.890119
# 1                 2.305917
# 2                      NaN
# 3                 5.060032
# 4                -0.586156
# ...                    ...
# 7738              2.438267
# 7739              1.881175
# 7740             -0.347644
# 7741              2.757514
# 7742              3.132729
#
# [7743 rows x 36 columns]

# %%
df_siren.to_csv('api_siren_final.csv')

# %%
df['SIREN'].value_counts()
# Out:
# Non disponible    3902
# 431857317            4
# 494855406            4
# 377550249            4
# 379548001            4
#                   ...
# 910918291            1
# 901039644            1
# 334027141            1
# 844955658            1
# 845183110            1
# Name: SIREN, Length: 7701, dtype: int64

# %%
df['SIREN'].isna().sum()
# Out:
# 2712

# %%
df_siren
# Out:
#                       nom                                        description  \
# 5      1001-ARCHITECTURES        1001 Façons de sublimer votre espace de vie
# 7          1001PHARMACIES  Achetez sur internet chez les pharmacies franç...
# 8                    100M  100M simplifie la production du reporting trad...
# 9                    1083              Manufacture jeans and shoes in France
# 10                  10H11  10h11 est une société technologique dans l’opt...
# ...                   ...                                                ...
# 14330               ZORBA  Bringing purpose to stories while exploring li...
# 14332               ZOZIO  The first digital companion of the industrial ...
# 14336               ZYGON  Comprehensive SaaS security solution offering ...
# 14338                 ZYL  Zyl (anciennement Comet) est une application m...
# 14339            ZYMOPTIQ  En facilitant la mesure enzymatique, nous rend...
#
#                                                     logo  \
# 5      https://d3kqkuy1hpjocx.cloudfront.net/s3fs-pub...
# 7      https://storage.googleapis.com/dealroom-images...
# 8      https://upload.prd.hbd.cloud.bpifrance.fr/star...
# 9      https://storage.googleapis.com/dealroom-images...
# 10     https://storage.googleapis.com/dealroom-images...
# ...                                                  ...
# 14330  https://storage.googleapis.com/dealroom-images...
# 14332  https://maddyness.twic.pics/2022/05/Capture-de...
# 14336  https://storage.googleapis.com/dealroom-images...
# 14338  https://maddyness.twic.pics/2019/09/Logo-Zyl.p...
# 14339  https://storage.googleapis.com/dealroom-images...
#
#       Date dernier financement     Série LinkedIn Type d'organisme  \
# 5                          NaN       NaN      NaN              NaN
# 7                          NaN       NaN      NaN              NaN
# 8                          NaN       NaN      NaN              NaN
# 9                          NaN       NaN      NaN              NaN
# 10                         NaN       NaN      NaN              NaN
# ...                        ...       ...      ...              ...
# 14330                      NaN       NaN      NaN              NaN
# 14332               2022-01-05  Amorçage      NaN              NaN
# 14336                      NaN       NaN      NaN              NaN
# 14338                      NaN       NaN      NaN              NaN
# 14339                      NaN       NaN      NaN              NaN
#
#       Activité principale market valeur_entreprise  \
# 5                     NaN    NaN               NaN
# 7                  64.20Z    B2C           €32—49m
# 8                  58.29A    NaN               NaN
# 9                     NaN    B2C             €4—6m
# 10                 58.29C    B2C               NaN
# ...                   ...    ...               ...
# 14330                 NaN    B2B               NaN
# 14332              62.02A    B2B           €16—24m
# 14336                 NaN    B2B           €11—16m
# 14338              14.13Z    NaN               NaN
# 14339              74.90B    B2B           €12—18m
#
#                                            mots_cles_def      Effectif_def  \
# 5                                                habitat               NaN
# 7      telecommunications, marketplace, , e-commerce,...    3 à 5 salariés
# 8                                        , bretagne, b2b               NaN
# 9          fashion, manufacturing, selling own inventory  50 à 99 salariés
# 10     , gironde, nouvelle-aquitaine, bordeaux, b2b, ...  20 à 49 salariés
# ...                                                  ...               ...
# 14330                            marketing, subscription  50 à 99 salariés
# 14332  , enterprise software, artificial intelligence...  20 à 49 salariés
# 14336                       saas, security, subscription    3 à 5 salariés
# 14338                                                NaN               NaN
# 14339  , selling own inventory, health, biotechnology...               NaN
#
#                                             site_web_def  \
# 5      https://1001-architectures.fr/?utm_source=LesP...
# 7                        https://www.1001pharmacies.com/
# 8                                                    NaN
# 9                                                    NaN
# 10                                https://www.10h11.com/
# ...                                                  ...
# 14330                                                NaN
# 14332                                https://zozio.tech/
# 14336                                                NaN
# 14338                                    https://zyl.ai/
# 14339                              https://zymoptiq.com/
#
#                       adresse_def date_creation_def  Nom Prenom Poste  \
# 5        15 Rue des Halles, Paris               NaN  NaN    NaN   NaN
# 7             Montpellier, France        2015-06-09  NaN    NaN   NaN
# 8                             NaN        2016-09-30  NaN    NaN   NaN
# 9        Romans-sur-Isère, France        2013-01-01  NaN    NaN   NaN
# 10     Bordeaux, Bordeaux, France        2011-03-07  NaN    NaN   NaN
# ...                           ...               ...  ...    ...   ...
# 14330               Paris, France        2003-01-01  NaN    NaN   NaN
# 14332               Paris, France               NaN  NaN    NaN   NaN
# 14336               Paris, France        2023-01-01  NaN    NaN   NaN
# 14338                         NaN        2019-10-29  NaN    NaN   NaN
# 14339            Lezennes, France        2019-01-01  NaN    NaN   NaN
#
#       Montant_def      SIREN
# 5             NaN  841823347
# 7             NaN  812052017
# 8             NaN  823095401
# 9             NaN  804409134
# 10            NaN  531294296
# ...           ...        ...
# 14330         NaN  342951761
# 14332   4000000.0  844245464
# 14336         NaN  977905678
# 14338         NaN  878792704
# 14339         NaN  845183110
#
# [7743 rows x 20 columns]
