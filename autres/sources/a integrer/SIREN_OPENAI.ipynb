# %%
import streamlit as st
import pandas as pd
import openai
import os
import time
from dotenv import load_dotenv, find_dotenv

# 🔹 Charger les variables d'environnement
_ = load_dotenv(find_dotenv())

# 🔹 Configurer OpenAI
client = openai.OpenAI(api_key=os.environ.get('OPENAI_API_KEY'))

# 🔹 Fonction pour charger les données SIREN
@st.cache_data
def load_data(file_path):
    df = pd.read_csv(file_path, sep=',')  # Vérifie le séparateur
    return df

def get_keyword_from_openai(description):
    """
    Utilise l'API OpenAI pour récupérer les mots clés d'une entreprise à partir de sa description.
    """
    if pd.isna(description) or description.strip() == "":
        return "Pas de description"

    try:
        print("\n" + "=" * 60)
        print(f"🔎 Recherche des mots clés pour : {description[:50]}...")

        # 🔹 Prompt détaillé
        prompt = (
            f"À partir de la description suivante, génère **4 mots-clés** "
            "qui décrivent **le plus précisément possible** l'entreprise."
            "Les mots-clés doivent être représentatifs du secteur, de la technologie ou du marché cible."
            "Les mots clés doivent être simple en un seul mot. Pas #ContentCreation ou DigitalWorkplace qui sont 2 mots collés."
            "Utilise **des hashtags** si pertinent (ex: #3DPrinting, #IA, #Fintech)."
            "\n\n"
            f"Description : {description}\n"
            "Mots-clés :"
        )

        # 🔹 Appel à l'API OpenAI
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Tu es un expert en technologies et en analyse de marché."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=50,
            temperature=0.2
        )

        # 🔹 Extraction de la réponse
        keywords = response.choices[0].message.content.strip()

        print(f"✅ Mots-clés trouvés : {keywords}")
        return keywords

    except Exception as e:
        print(f"❌ Erreur pour la description '{description[:50]}...': {e}")
        return "Erreur"

# 🔹 Charger le fichier CSV contenant les entreprises
input_csv = "mot_cles_openai_clean.csv"  # Remplace par ton fichier source
output_csv = "resul_mot_cles.csv"

df = load_data(input_csv)

# 🔹 Vérifier si la colonne "mots_cles" existe déjà, sinon la créer
if "mots_cles" not in df.columns:
    df["mots_cles"] = None

# 🔹 Remplir les mots-clés pour les entreprises qui n'en ont pas encore
for index, row in df.iterrows():
    if pd.isna(row["mots_cles"]) or row["mots_cles"].strip() == "":
        df.at[index, "mots_cles"] = get_keyword_from_openai(row["description"])
        time.sleep(1)  # 🔹 Pause pour éviter les limitations d'OpenAI

# 🔹 Sauvegarder le fichier mis à jour
df.to_csv(output_csv, index=False)

print(f"✅ Fichier enregistré : {output_csv}")
# Out:
# 2025-01-31 23:03:14.094 No runtime found, using MemoryCacheStorageManager
# 2025-01-31 23:03:14.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-31 23:03:14.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-31 23:03:14.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-31 23:03:14.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-31 23:03:14.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ============================================================
# 🔎 Recherche des mots clés pour : Klaxoon is an all-in-one work collaboration platfo...
# ✅ Mots-clés trouvés : #Collaboration, #Productivité, #Engagement, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Pitchy is a simplified online video editor for lar...
# ✅ Mots-clés trouvés : #VideoEditing, #Corporate, #AI, #ContentCreation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Contentsquare is a leading digital experience anal...
# ✅ Mots-clés trouvés : #Analytics, #UX, #IA, #DigitalExperience
#
# ============================================================
# 🔎 Recherche des mots clés pour : Braincube offers innovative digital solutions, bac...
# ✅ Mots-clés trouvés : #IA, #Manufacturing, #Sustainability, #DataAnalytics
#
# ============================================================
# 🔎 Recherche des mots clés pour : Deepomatic is a pioneer in the field of First Time...
# ✅ Mots-clés trouvés : #IA, #ComputerVision, #Automation, #Infrastructure
#
# ============================================================
# 🔎 Recherche des mots clés pour : DAVI AI provides Digital Employees with profession...
# ✅ Mots-clés trouvés : #IA, #Automatisation, #Productivité, #Collaborateurs
#
# ============================================================
# 🔎 Recherche des mots clés pour : Energiency helps manufacturers to achieve new ener...
# ✅ Mots-clés trouvés : #Energie, #IA, #Industrie, #Durabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Today, 80% of cyberattacks exploit human vulnerabi...
# ✅ Mots-clés trouvés : #Cybersécurité, #Fraude, #ProtectionIdentité, #RGPD
#
# ============================================================
# 🔎 Recherche des mots clés pour : DiagRAMS Technologies propose une solution de surv...
# ✅ Mots-clés trouvés : #IA, #Industrie, #Maintenance, #Algorithmes
#
# ============================================================
# 🔎 Recherche des mots clés pour : DiagRAMS Technologies propose une solution de surv...
# ✅ Mots-clés trouvés : #IA, #Maintenance, #Industrie, #Surveillance
#
# ============================================================
# 🔎 Recherche des mots clés pour : The service provided by InVirtus is made of 2 main...
# ✅ Mots-clés trouvés : #Geolocation, #IoT, #AI, #AssetManagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Founded in 2018, TechnoCarbon is a startup special...
# ✅ Mots-clés trouvés : #Composite, #Sustainability, #Decarbonization, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : A comprehensive business management platform equip...
# ✅ Mots-clés trouvés : #POS, #IA, #Retail, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Toporder, founded in 2019, leads in point-of-sale ...
# ✅ Mots-clés trouvés : #POS, #IA, #Retail, #Analytics
#
# ============================================================
# 🔎 Recherche des mots clés pour : Connected Cycle provides connectivity, location tr...
# ✅ Mots-clés trouvés : #Micromobility, #Telematics, #IoT, #FleetManagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : FLYING WHALES is a French aeronautic start-up esta...
# ✅ Mots-clés trouvés : #Aéronautique, #Dirigeable, #Décarbonisation, #Fret
#
# ============================================================
# 🔎 Recherche des mots clés pour : SCINTIL Photonics is a fabless company that develo...
# ✅ Mots-clés trouvés : #Photonics, #DataCenters, #5G, #Semiconductors
#
# ============================================================
# 🔎 Recherche des mots clés pour : Primaa offers an AI-based platform for automated a...
# ✅ Mots-clés trouvés : #Medtech, #IA, #DeepLearning, #CancerDiagnosis
#
# ============================================================
# 🔎 Recherche des mots clés pour : Ÿnsect is one of the world leader in the productio...
# ✅ Mots-clés trouvés : #InsectProtein, #Sustainability, #VerticalFarming, #AgriTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : Preligens was founded in 2016 by two French engine...
# ✅ Mots-clés trouvés : #IA, #Geospatial, Défense, Aérospatial
#
# ============================================================
# 🔎 Recherche des mots clés pour : WeMaintain is a scale-up with 250 employees in Eur...
# ✅ Mots-clés trouvés : #PropTech, #IoT, #Maintenance, #Durabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Since 2019, Unseenlabs operates a cutting-edge sat...
# ✅ Mots-clés trouvés : #Satellite, #Surveillance, #Maritime, #Intelligence
#
# ============================================================
# 🔎 Recherche des mots clés pour : In disease diagnostics, every second counts. Advan...
# ✅ Mots-clés trouvés : #Genomics, #Oncology, #AI, #Healthcare
#
# ============================================================
# 🔎 Recherche des mots clés pour : Sonio is a highly customizable workflow and practi...
# ✅ Mots-clés trouvés : #IA, #Ultrasound, #Prenatal, #Automation
#
# ============================================================
# 🔎 Recherche des mots clés pour : CROSSCALL, a durable mobile telephony creator, off...
# ✅ Mots-clés trouvés : #Durabilité, #Téléphonie, #Outdoor, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Nomad Education is an impact-driven tech company t...
# ✅ Mots-clés trouvés : #EdTech, #IA, #MobileLearning, #Inclusivity
#
# ============================================================
# 🔎 Recherche des mots clés pour : Innovation management platform fueled by 10M start...
# ✅ Mots-clés trouvés : #Innovation, #Startups, #OpenInnovation, #Software
#
# ============================================================
# 🔎 Recherche des mots clés pour : Malt is a digital marketplace that connects busine...
# ✅ Mots-clés trouvés : #Freelance, #Marketplace, #Consulting, #TechTalent
#
# ============================================================
# 🔎 Recherche des mots clés pour : Toucan is a customer-facing analytics platform tha...
# ✅ Mots-clés trouvés : #Analytics, #DataStorytelling, #NoCode, #Cloud
#
# ============================================================
# 🔎 Recherche des mots clés pour : Hxperience designs and operates digital services f...
# ✅ Mots-clés trouvés : #SmartBuilding, #SaaS, #IoT, #EnergyEfficiency
#
# ============================================================
# 🔎 Recherche des mots clés pour : Amiral Technologies is a spin-off of French CNRS. ...
# ✅ Mots-clés trouvés : #IA, #Industrie, #Algorithmes, #Capteurs
#
# ============================================================
# 🔎 Recherche des mots clés pour : United Heroes is the employee engagement app for i...
# ✅ Mots-clés trouvés : #Wellbeing, #Engagement, #Cohesion, #Employee
#
# ============================================================
# 🔎 Recherche des mots clés pour : Enertime is specialized in the development of inno...
# ✅ Mots-clés trouvés : #ORC, #Geothermal, #Biomass, #Decarbonization
#
# ============================================================
# 🔎 Recherche des mots clés pour : Studio Nyx specializes in high-quality 3D and inte...
# ✅ Mots-clés trouvés : #3D, #Simulation, #Agriculture, #Viticulture
#
# ============================================================
# 🔎 Recherche des mots clés pour : Orosound is a French technology company, and the o...
# ✅ Mots-clés trouvés : #Audio, #Technologie, #Durabilité, #IA
#
# ============================================================
# 🔎 Recherche des mots clés pour : Sparkup is a comprehensive virtual, hybrid and in-...
# ✅ Mots-clés trouvés : #EventTech, #HybridEvents, #Webinars, #Engagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Spendesk is the complete spend management platform...
# ✅ Mots-clés trouvés : #Fintech, #Automation, #SpendManagement, #FinanceCommunity
#
# ============================================================
# 🔎 Recherche des mots clés pour : Mooncard, the reinvented expense management soluti...
# ✅ Mots-clés trouvés : #Fintech, #ExpenseManagement, #Automation, #PaymentCards
#
# ============================================================
# 🔎 Recherche des mots clés pour : CryptoNext Security, based in Paris, founded in 20...
# ✅ Mots-clés trouvés : #Cryptographie, #PostQuantique, #Cybersécurité, #Logiciel
#
# ============================================================
# 🔎 Recherche des mots clés pour : bloomUp is a global consultancy agency leader in s...
# ✅ Mots-clés trouvés : #Sustainability, #Innovation, #Regenerative, #DataInsights
#
# ============================================================
# 🔎 Recherche des mots clés pour : Bienvenue chez Plume, où la mobilité rencontre l'e...
# ✅ Mots-clés trouvés : #Mobilité, #Électrique, #Durabilité, #MadeInFrance
#
# ============================================================
# 🔎 Recherche des mots clés pour : With Uptale, the leader in Immersive and Spatial L...
# ✅ Mots-clés trouvés : #ImmersiveLearning, #SpatialLearning, #AI, #360Video
#
# ============================================================
# 🔎 Recherche des mots clés pour : With Uptale, the leader in Immersive and Spatial L...
# ✅ Mots-clés trouvés : #ImmersiveLearning, #SpatialLearning, #AI, #360Video
#
# ============================================================
# 🔎 Recherche des mots clés pour : Publisher of SaaS solutions and trusted third part...
# ✅ Mots-clés trouvés : #SaaS, #Automatisation, #Sécurité, #SignatureÉlectronique
#
# ============================================================
# 🔎 Recherche des mots clés pour : Dawex is the leader in Data Exchange solutions to ...
# ✅ Mots-clés trouvés : #DataExchange, #Ecosystem, #Regulations, #Decarbonation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Blue Frog Robotics embodies AI with Buddy the AI d...
# ✅ Mots-clés trouvés : #Robotique #IA #Éducation #Santé
#
# ============================================================
# 🔎 Recherche des mots clés pour : Mini Green Power designs and installs "Mini Green ...
# ✅ Mots-clés trouvés : #ÉnergieVerte, #Cogénération, #TraitementDéchets, #Biochar
#
# ============================================================
# 🔎 Recherche des mots clés pour : Avec la solution de mobilité participative wever, ...
# ✅ Mots-clés trouvés : #Mobilité, #IA, #Transport, #Participation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Platform.sh provides a reliable, stable, and secur...
# ✅ Mots-clés trouvés : #Cloud, #DevOps, #Scalability, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : Cosmo Tech provides AI Simulation and digital twin...
# ✅ Mots-clés trouvés : #Simulation, #DigitalTwins, #AI, #PredictiveAnalytics
#
# ============================================================
# 🔎 Recherche des mots clés pour : Comet is the fastest growing tech-enabled company,...
# ✅ Mots-clés trouvés : #TalentMatching, #AI, #DigitalStaffing, #TechEcosystem
#
# ============================================================
# 🔎 Recherche des mots clés pour : Trust is the ultimate human currency, yet we live ...
# ✅ Mots-clés trouvés : #Finance, #SaaS, #Compliance, #Audit
#
# ============================================================
# 🔎 Recherche des mots clés pour : m-work is an all-in-one platform that optimizes th...
# ✅ Mots-clés trouvés : #HybridWork, #PropTech, #TeamCollaboration, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : Sopht is a data-driven solution to measure, pilot,...
# ✅ Mots-clés trouvés : #Décarbonisation, #Automatisation, #Données, #IT
#
# ============================================================
# 🔎 Recherche des mots clés pour : Wintics transforms ordinary cameras into monitorin...
# ✅ Mots-clés trouvés : #SmartCities, #VideoAnalytics, #UrbanMonitoring, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : Wintics is a French company specializing in the de...
# ✅ Mots-clés trouvés : #VideoAnalysis, #SmartCity, #UrbanMobility, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : We automate trivial tasks to save 60% time of digi...
# ✅ Mots-clés trouvés : #Automatisation, #Ecommerce, #IA, #Productivité
#
# ============================================================
# 🔎 Recherche des mots clés pour : LookAroun is a groundbreaking mobile application d...
# ✅ Mots-clés trouvés : #Networking, #EventTech, #RealTime, #Engagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Emvista is a French company based in Montpellier. ...
# ✅ Mots-clés trouvés : #IA, #TextMining, #Anonymization, #Souveraineté
#
# ============================================================
# 🔎 Recherche des mots clés pour : MEDADOM is a French Tech 120 startup that is revol...
# ✅ Mots-clés trouvés : #Telemedicine, #Healthcare, #MedTech, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Cosmian is revolutionizing Data Protection with it...
# ✅ Mots-clés trouvés : #Cryptography, #Encryption, #ConfidentialComputing, #DataProtection
#
# ============================================================
# 🔎 Recherche des mots clés pour : Your smart, secure and reusable shipments. The exp...
# ✅ Mots-clés trouvés : #SmartPackaging, #Logistics, #Sustainability, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Buster.Ai is your digital shield against misleadin...
# ✅ Mots-clés trouvés : #Cybersecurity, #Misinformation, #GenerativeAI, #SaaS
#
# ============================================================
# 🔎 Recherche des mots clés pour : A pioneer in the market since 2005, Opteamis suppo...
# ✅ Mots-clés trouvés : #Procurement, #ITServices, #Platform, #Automation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Centiloc is a French company whose mission is to r...
# ✅ Mots-clés trouvés : #Geolocation, #NFC, Inventaire, #Automatisation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Meersens - labeled #GreenTech & #DeepTech - is a p...
# ✅ Mots-clés trouvés : #GreenTech, #DeepTech, #IoT, #SaaS
#
# ============================================================
# 🔎 Recherche des mots clés pour : Impact start-up Biomede (top 500 world deeptech, N...
# ✅ Mots-clés trouvés : #Deeptech, #IA, Phytoremédiation, #Environnement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Stripe est le leader mondial en matière de process...
# ✅ Mots-clés trouvés : #Fintech, #Ecommerce, Paiements, Infrastructure
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Sans une description spécifique de l'entreprise, il est difficile de générer des mots-clés précis. Cependant, je peux vous fournir quelques exemples génériques basés sur des secteurs technologiques courants. Voici quelques suggestions :
#
# 1. #IA
# 2
#
# ============================================================
# 🔎 Recherche des mots clés pour : Greenly makes carbon footprinting precise, intuiti...
# ✅ Mots-clés trouvés : #Sustainability, #CarbonFootprint, #GreenIT, #ClimateStrategy
#
# ============================================================
# 🔎 Recherche des mots clés pour : Founded in 2015 by William Eldin, and winner of Fr...
# ✅ Mots-clés trouvés : #ComputerVision, #AI, #TechInnovation, #HumanAugmentation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Bodyguard is a social media monitoring and moderat...
# ✅ Mots-clés trouvés : #Modération, #IA, #Sécurité, #Communautés
#
# ============================================================
# 🔎 Recherche des mots clés pour : Thanks to their cooperation with providers and man...
# ✅ Mots-clés trouvés : #HealthTech, #AI, #MedicalImaging, #Radiology
#
# ============================================================
# 🔎 Recherche des mots clés pour : Numalis is a Montpellier-based software company th...
# ✅ Mots-clés trouvés : #IA, #SaaS, #Standardisation, #Robustesse
#
# ============================================================
# 🔎 Recherche des mots clés pour : YouScribe allows you to read anywhere, anytime. Wh...
# ✅ Mots-clés trouvés : #DigitalLibrary, #Ebooks, #Audiobooks, #EdTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : VoltR is a French manufacturer specialized in seco...
# ✅ Mots-clés trouvés : #Recyclage #Batteries #ÉconomieCirculaire #Durabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : AquaTech Innovation is a GreenTech start-up based ...
# ✅ Mots-clés trouvés : #GreenTech, #WaterConservation, #WastewaterTreatment, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : miLibris is a market-leading French tech company t...
# ✅ Mots-clés trouvés : #Digitalisation, #Ebooks, #MediaTech, #ContentDistribution
#
# ============================================================
# 🔎 Recherche des mots clés pour : AI to drive marketing pressure & orchestrate omnic...
# ✅ Mots-clés trouvés : #IA, #CRM, #Omnicanal, #MarTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : Established in 2019 in San Francisco and currently...
# ✅ Mots-clés trouvés : #Geospatial, #Mobility, #SmartCities, #DataManagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Ippon Technologies est un cabinet de conseil et d'...
# ✅ Mots-clés trouvés : #Cloud, #Data, #Transformation, #Design
#
# ============================================================
# 🔎 Recherche des mots clés pour : CogNeed offers innovative AI-powered solutions for...
# ✅ Mots-clés trouvés : #IA, #Chatbot, #CRM, #Ventes
#
# ============================================================
# 🔎 Recherche des mots clés pour : ANAPIX medical, co-founded by Bernard Fertil, form...
# ✅ Mots-clés trouvés : #MedTech, #IA, #Dermatology, #Telemedicine
#
# ============================================================
# 🔎 Recherche des mots clés pour : Voltaage helps EV Charge Point Operators maximize ...
# ✅ Mots-clés trouvés : #EV, #AI, #Analytics, #ROI
#
# ============================================================
# 🔎 Recherche des mots clés pour : Popsell is a personal shopper platform that puts s...
# ✅ Mots-clés trouvés : #Omnichannel, #Phygital, #Ecommerce, #CustomerLoyalty
#
# ============================================================
# 🔎 Recherche des mots clés pour : Imagine a world where the boundaries of technology...
# ✅ Mots-clés trouvés : #Neurotechnology, #IA, #Innovation, #Accessibility
#
# ============================================================
# 🔎 Recherche des mots clés pour : The ORCAD Project (ORal CAncer Detection) aims to ...
# ✅ Mots-clés trouvés : #Santé, #IA, #Détection, #Cancer
#
# ============================================================
# 🔎 Recherche des mots clés pour : STOLECT is developing a large-scale electricity st...
# ✅ Mots-clés trouvés : #ÉnergieRenouvelable, #StockageÉlectrique, #TransitionÉnergétique, #Décarbonisation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Televet is a pet tech company, connecting pet pare...
# ✅ Mots-clés trouvés : #PetTech, #Telehealth, #Veterinary, #MobileServices
#
# ============================================================
# 🔎 Recherche des mots clés pour : Purple Alternative Surface est une start-up innova...
# ✅ Mots-clés trouvés : #Écologie, #Recyclage, #BTP, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : The KeoPass Biometric Key is an all-in-one standal...
# ✅ Mots-clés trouvés : #Biométrie, #Sécurité, #Authentification, #Accès
#
# ============================================================
# 🔎 Recherche des mots clés pour : TORSKAL is an international biotech/medtech compan...
# ✅ Mots-clés trouvés : #Biotech, #Nanotechnology, #GreenChemistry, #CancerTherapy
#
# ============================================================
# 🔎 Recherche des mots clés pour : Cocolis is a leading collaborative logistics servi...
# ✅ Mots-clés trouvés : #Logistics, #Sustainability, #Ecommerce, #API
#
# ============================================================
# 🔎 Recherche des mots clés pour : Olvid is the very first private messenger, availab...
# ✅ Mots-clés trouvés : #Privacy, #Encryption, #Messenger, #Security
#
# ============================================================
# 🔎 Recherche des mots clés pour : Altametris, a subsidiary of SNCF Réseau, provides ...
# ✅ Mots-clés trouvés : #Infrastructure, #DigitalTwin, #DataProcessing, #Engineering
#
# ============================================================
# 🔎 Recherche des mots clés pour : Eisox has developed the only technology on the mar...
# ✅ Mots-clés trouvés : #SmartBuilding, #EnergyEfficiency, #IoT, #PropTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : Inuk empowers businesses and individuals to reliab...
# ✅ Mots-clés trouvés : #Blockchain, #Renouvelable, #IA, #Carbone
#
# ============================================================
# 🔎 Recherche des mots clés pour : All-in-one platform to empower your Community ! Ma...
# ✅ Mots-clés trouvés : #Community
# #Branding
# #Webinars
# #Networking
#
# ============================================================
# 🔎 Recherche des mots clés pour : Tale of Data is an AI-Powered Data Quality Platfor...
# ✅ Mots-clés trouvés : #IA, #NoCode, #DataQuality, #Entreprise
#
# ============================================================
# 🔎 Recherche des mots clés pour : Tripartie is a user disputes prevention & resoluti...
# ✅ Mots-clés trouvés : #DisputeResolution, #Automation, #FraudDetection, #Ewallet
#
# ============================================================
# 🔎 Recherche des mots clés pour : Make innovation a daily practice in your organizat...
# ✅ Mots-clés trouvés : #Innovation, #DigitalPlatform, #Consulting, #Workshops
#
# ============================================================
# 🔎 Recherche des mots clés pour : AGIGA est une société à mission qui met à disposit...
# ✅ Mots-clés trouvés : #ÉconomieCirculaire, #Électronique, #Marketplace, #Durabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Business France has a clear mission: to propel Fre...
# ✅ Mots-clés trouvés : #Export, #Investissement, #Entrepreneuriat, #International
#
# ============================================================
# 🔎 Recherche des mots clés pour : Capgemini is a global business and technology tran...
# ✅ Mots-clés trouvés : #Transformation, #Cloud, #IA, #Durabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : The CEA is tasked with guiding public decisions an...
# ✅ Mots-clés trouvés : #Innovation, #Recherche, #Technologie, #TransitionÉnergétique
#
# ============================================================
# 🔎 Recherche des mots clés pour : The National Centre for Scientific Research (CNRS)...
# ✅ Mots-clés trouvés : #Research, #Innovation, #DeepTech, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : elow is an application that enables companies to r...
# ✅ Mots-clés trouvés : #GreenTech, #EnergyEfficiency, #Sustainability, #EcoSoftware
#
# ============================================================
# 🔎 Recherche des mots clés pour : Enedis, le service public de la transition écologi...
# ✅ Mots-clés trouvés : #Électricité, #Transition, #Réseau, #Sobriété
#
# ============================================================
# 🔎 Recherche des mots clés pour : The PULSE is an industrial machine that converts l...
# ✅ Mots-clés trouvés : #Thermodynamics, #WasteHeat, #Decarbonization, #GreenEnergy
#
# ============================================================
# 🔎 Recherche des mots clés pour : France Travail a remplacé Pôle emploi au 1er janvi...
# ✅ Mots-clés trouvés : #Emploi, #Recrutement, #Insertion, #Formation
#
# ============================================================
# 🔎 Recherche des mots clés pour : L’Institut national de la propriété industrielle (...
# ✅ Mots-clés trouvés : #PropriétéIntellectuelle, #Innovation, #Brevets, #Compétitivité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Inria is the French national research institute fo...
# ✅ Mots-clés trouvés : #Recherche, #Innovation, #Deeptech, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : Kikleo is a startup founded in September 2019, aim...
# ✅ Mots-clés trouvés : #FoodTech, #IA, #Sustainability, #DataAnalysis
#
# ============================================================
# 🔎 Recherche des mots clés pour : KPMG in France is a leading audit and advisory fir...
# ✅ Mots-clés trouvés : #Audit, #Conseil, #Innovation, #Responsabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Mob-Energy designs, manufactures, deploys and supe...
# ✅ Mots-clés trouvés : #EVCharging, #EnergyStorage, #SecondLifeBatteries, #Scalability
#
# ============================================================
# 🔎 Recherche des mots clés pour : Orange is one of the world’s leading telecommunica...
# ✅ Mots-clés trouvés : #Telecommunications, #Mobile, #Broadband, #ITServices
#
# ============================================================
# 🔎 Recherche des mots clés pour : Quobly is a pioneer in the development of quantum ...
# ✅ Mots-clés trouvés : #QuantumComputing, #Semiconductors, #SpinQubits, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : La Société TI3RS est une société de l'Economie Soc...
# ✅ Mots-clés trouvés : #EconomieSolidaire, #Sécurité, #ApplicationMobile, #ViolenceConjugale
#
# ============================================================
# 🔎 Recherche des mots clés pour : TotalEnergies is a global multi-energy company tha...
# ✅ Mots-clés trouvés : #Energies, #Renewables, #Sustainability, #Electricity
#
# ============================================================
# 🔎 Recherche des mots clés pour : WP connect’s suite of plugins and add-ons facilita...
# ✅ Mots-clés trouvés : #NoCode, #WordPress, #Integration, #Ecommerce
#
# ============================================================
# 🔎 Recherche des mots clés pour : Founded in 2021, Livmed's is a gem from Nice in th...
# ✅ Mots-clés trouvés : #EHealth, #Pharmacie, Livraison, #Santé
#
# ============================================================
# 🔎 Recherche des mots clés pour : LVMH is the world leader in luxury with 75 unique ...
# ✅ Mots-clés trouvés : #Luxe, #Mode, #Parfumerie, #Vins
#
# ============================================================
# 🔎 Recherche des mots clés pour : Luniwave helps hoteliers reduce their water and en...
# ✅ Mots-clés trouvés : #Sustainability, #IoT, #Hospitality, #Gamification
#
# ============================================================
# 🔎 Recherche des mots clés pour : Mago Essential: hassle-free wireless presentation ...
# ✅ Mots-clés trouvés : #Wireless, #Collaboration, #DigitalSignage, #VideoConferencing
#
# ============================================================
# 🔎 Recherche des mots clés pour : Our technology is a breakthrough innovation in dyn...
# ✅ Mots-clés trouvés : #Chimie, #Recyclage, #Écologie, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Revolutionizing Employee Benefits At May, we belie...
# ✅ Mots-clés trouvés : #Fintech, #Benefits, #Employee, #Platform
#
# ============================================================
# 🔎 Recherche des mots clés pour : Mendo drives the deployment and adoption of genera...
# ✅ Mots-clés trouvés : #IA, #Formation, #Entreprise, #Intégration
#
# ============================================================
# 🔎 Recherche des mots clés pour : Mistral AI is a cutting-edge company based in Pari...
# ✅ Mots-clés trouvés : #IA, #Éthique, #ModèlesLinguistiques, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Netcarbon markets Netcarbon Intelligence, a platfo...
# ✅ Mots-clés trouvés : #SaaS, #Renaturation, #CarbonCertification, #EnvironmentalMonitoring
#
# ============================================================
# 🔎 Recherche des mots clés pour : We believe in the power of knowledge. We believe i...
# ✅ Mots-clés trouvés : #EdTech, #IA, #CognitiveSciences, #Learning
#
# ============================================================
# 🔎 Recherche des mots clés pour : Nijta protects audio recordings collected at conta...
# ✅ Mots-clés trouvés : #Anonymisation, #Biométrie, #Confidentialité, #Sécurité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Nijta protects audio recordings collected at conta...
# ✅ Mots-clés trouvés : #Anonymisation, #Sécurité, #Audio, #Confidentialité
#
# ============================================================
# 🔎 Recherche des mots clés pour : NuMind is a local app that allows you to easily cr...
# ✅ Mots-clés trouvés : #NLP, #Automation, #DataPrivacy, #CostEfficiency
#
# ============================================================
# 🔎 Recherche des mots clés pour : In the current context of climate emergency, the e...
# ✅ Mots-clés trouvés : #SmartGrid, #Energie, #IoT, #EcoResponsable
#
# ============================================================
# 🔎 Recherche des mots clés pour : Odaptos specializes in automated consumer testing....
# ✅ Mots-clés trouvés : #IA, #ReconnaissanceFaciale, #TestUtilisateur, #AnalyseÉmotionnelle
#
# ============================================================
# 🔎 Recherche des mots clés pour : Octopize has developed a unique solution for anony...
# ✅ Mots-clés trouvés : #Anonymisation, #Données, #Confidentialité, #Logiciel
#
# ============================================================
# 🔎 Recherche des mots clés pour : OCHY offers an innovative technology solution that...
# ✅ Mots-clés trouvés : #IA, #SportTech, #Coaching, #Running
#
# ============================================================
# 🔎 Recherche des mots clés pour : Orakl Oncology ambitions to bring back patients tu...
# ✅ Mots-clés trouvés : #Oncologie, #Techbio, #MachineLearning, #Biopharma
#
# ============================================================
# 🔎 Recherche des mots clés pour : Outsight's software solutions track and digitize h...
# ✅ Mots-clés trouvés : 1. #LiDAR
# 2. #SpatialIntelligence
# 3. #Transportation
# 4. #Safety
#
# ============================================================
# 🔎 Recherche des mots clés pour : Outmind is an AI-powered Knowledge Management Solu...
# ✅ Mots-clés trouvés : #IA, #Productivité, #Recherche, #Information
#
# ============================================================
# 🔎 Recherche des mots clés pour : Immersed in a realistic environment, the learner f...
# ✅ Mots-clés trouvés : #EdTech, #VR, #NLU, #CognitiveLearning
#
# ============================================================
# 🔎 Recherche des mots clés pour : Our vision is to become the leading anti-waste pla...
# ✅ Mots-clés trouvés : #AntiWaste, #FoodTech, #Subscription, #LocalDistribution
#
# ============================================================
# 🔎 Recherche des mots clés pour : Pigment is a business planning platform that provi...
# ✅ Mots-clés trouvés : #Planification, #Analyse, #Stratégie, #Entreprise
#
# ============================================================
# 🔎 Recherche des mots clés pour : Popsink takes away the cost, latency and complexit...
# ✅ Mots-clés trouvés : #DataIntegration, #RealTime, #CloudMigration, #DataSynchronization
#
# ============================================================
# 🔎 Recherche des mots clés pour : AI-based solution integrating into SOC existing te...
# ✅ Mots-clés trouvés : #Cybersécurité, #IA, #Automatisation, #SOC
#
# ============================================================
# 🔎 Recherche des mots clés pour : Qarnot is a French cloud service provider, whose a...
# ✅ Mots-clés trouvés : 1. #CloudComputing
# 2. #GreenTech
# 3. #DigitalSovereignty
# 4. #DeepTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : For several years, the volatility of commodity pri...
# ✅ Mots-clés trouvés : #AgriTech, #Hedging, #Commodities, #RiskManagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Qubit Pharmaceuticals is a pioneering deep-tech co...
# ✅ Mots-clés trouvés : #PharmaTech, #QuantumComputing, #DrugDiscovery, #AI
#
# ============================================================
# 🔎 Recherche des mots clés pour : Quandela is a French startup specialising in photo...
# ✅ Mots-clés trouvés : #QuantumComputing, #Photonics, #Cloud, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Schoolab is an innovation studio that educates, ad...
# ✅ Mots-clés trouvés : #Innovation, #Entrepreneurship, #Sustainability, #Collaboration
#
# ============================================================
# 🔎 Recherche des mots clés pour : SAYNA connect learners to their first digital job ...
# ✅ Mots-clés trouvés : #EdTech, #Freelancing, #DigitalSkills, #Elearning
#
# ============================================================
# 🔎 Recherche des mots clés pour : Since 2017, Sêmeia has offered Wise a platform for...
# ✅ Mots-clés trouvés : #HealthTech, #DataScience, #PatientMonitoring, #ChronicCare
#
# ============================================================
# 🔎 Recherche des mots clés pour : Observe & Decode User Behavior Effortlessly : Scre...
# ✅ Mots-clés trouvés : #Analytics, #UserEngagement, #Feedback, #NoCode
#
# ============================================================
# 🔎 Recherche des mots clés pour : Co-built with 40 renowned hotels, our ambition is ...
# ✅ Mots-clés trouvés : #HospitalityTech, #Marketplace, #B2B, #DataManagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Sereema is a pioneering tech company focusing on w...
# ✅ Mots-clés trouvés : #WindEnergy, #Optimisation, #IoT, #Renewables
#
# ============================================================
# 🔎 Recherche des mots clés pour : SONUP's ambition is to accelerate the digital tran...
# ✅ Mots-clés trouvés : #Audiology, #DigitalHealth, #HearingTech, #MedTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : Sorella is a network of multidisciplinary health c...
# ✅ Mots-clés trouvés : #SantéFéminine, #Multidisciplinaire, #PlateformeDigitale, #BienÊtreProfessionnel
#
# ============================================================
# 🔎 Recherche des mots clés pour : Sopra Steria, acteur majeur de la Tech en Europe a...
# ✅ Mots-clés trouvés : #TransformationDigitale, #ServicesNumériques, #Conseil, #Logiciels
#
# ============================================================
# 🔎 Recherche des mots clés pour : Spotr is your go-to AI-powered platform, revolutio...
# ✅ Mots-clés trouvés : #PropTech, #IA, #InsurTech, #ComputerVision
#
# ============================================================
# 🔎 Recherche des mots clés pour : SPORTYNEO is a fintech platform dedicated to sport...
# ✅ Mots-clés trouvés : #Fintech, #Sports, #Payment, #Membership
#
# ============================================================
# 🔎 Recherche des mots clés pour : Created in 2020, Stoyfox is the startup that will ...
# ✅ Mots-clés trouvés : #Vidéo, #Startup, #Communication, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : Storio Energy develops and operates energy storage...
# ✅ Mots-clés trouvés : #Stockage, #Batteries, #Énergie, #Logiciel
#
# ============================================================
# 🔎 Recherche des mots clés pour : Stellar is a revolutionary SaaS software for cyber...
# ✅ Mots-clés trouvés : #Cybersecurity, #SaaS, #Automation, #Compliance
#
# ============================================================
# 🔎 Recherche des mots clés pour : Founded in 2022 as a spin-off from CEA-Leti and ba...
# ✅ Mots-clés trouvés : #LiDAR, #Photonics, #Autonomous, #SmartCities
#
# ============================================================
# 🔎 Recherche des mots clés pour : With its Solar Stations that can be plugged into a...
# ✅ Mots-clés trouvés : #SolarEnergy, #Renewables, #EnergyStorage, #DIY
#
# ============================================================
# 🔎 Recherche des mots clés pour : actiTENS is based on transcutaneous electrical neu...
# ✅ Mots-clés trouvés : #Neurostimulation, #MedTech, #PainManagement, #WearableTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : Founded in 2015 and based in Rennes with around 40...
# ✅ Mots-clés trouvés : #Osmotic, #Renouvelable, #Cleantech, #Énergie
#
# ============================================================
# 🔎 Recherche des mots clés pour : Le kit d'aménagement Tchao Tchao transforme notre ...
# ✅ Mots-clés trouvés : #Vanlife, #Aménagement, #Mobilité, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Toog is the first online platform for booking leis...
# ✅ Mots-clés trouvés : #Loisirs, #Réservation, #Plateforme, #EnLigne
#
# ============================================================
# 🔎 Recherche des mots clés pour : TOLV transforms ICE vehicles into electric. As a E...
# ✅ Mots-clés trouvés : #Retrofitting, #Electrification, #LCV, #Ecofriendly
#
# ============================================================
# 🔎 Recherche des mots clés pour : Treesition: Pioneering Sustainable Investments Wit...
# ✅ Mots-clés trouvés : #Sustainability, #Blockchain, #Reforestation, #GreenInvestments
#
# ============================================================
# 🔎 Recherche des mots clés pour : As a part of a quality of life at work approach, T...
# ✅ Mots-clés trouvés : #Bien-être, #Sport, #Santé, #Entreprise
#
# ============================================================
# 🔎 Recherche des mots clés pour : Trace For Good is the sustainability data enrichme...
# ✅ Mots-clés trouvés : #Durabilité, #IA, Traçabilité, #SupplyChain
#
# ============================================================
# 🔎 Recherche des mots clés pour : YCombinator-backed Trendex became one of the first...
# ✅ Mots-clés trouvés : #Tokenization, #Celebrities, #FanEngagement, #BrandAmbassadors
#
# ============================================================
# 🔎 Recherche des mots clés pour : UP&CHARGE: induction charging station for electric...
# ✅ Mots-clés trouvés : #Induction, #EVCharging, #B2BFleets, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : VIQTHOR offers an innovative Quantum Control Syste...
# ✅ Mots-clés trouvés : #QuantumComputing, #Photonics, #Qubits, #NoiseCancellation
#
# ============================================================
# 🔎 Recherche des mots clés pour : VIDETICS' core business is the development of vide...
# ✅ Mots-clés trouvés : #IA, #VideoAnalytics, #Security, #SmartCities
#
# ============================================================
# 🔎 Recherche des mots clés pour : WAAT est un opérateur français de bornes de rechar...
# ✅ Mots-clés trouvés : #MobilitéÉlectrique, #Recharge, #Durabilité, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : We also propose to reseal CO2 biogenic captured fo...
# ✅ Mots-clés trouvés : #CO2
# #Biogenic
# #Sustainability
# #Alimentary
#
# ============================================================
# 🔎 Recherche des mots clés pour : WATTALPS designs, assembles and sells high perform...
# ✅ Mots-clés trouvés : #Batteries #Electrification #ImmersionCooling #Industrie
#
# ============================================================
# 🔎 Recherche des mots clés pour : Community driven platform for telehealth and insur...
# ✅ Mots-clés trouvés : #Telehealth, #Insurtech, #MobileApp, Afrique
#
# ============================================================
# 🔎 Recherche des mots clés pour : Welinq est une société de réseautage quantique pio...
# ✅ Mots-clés trouvés : #QuantumNetworking, #QuantumComputing, #QuantumMemory, #Photonics
#
# ============================================================
# 🔎 Recherche des mots clés pour : Wise Integration is a pioneering company in the fi...
# ✅ Mots-clés trouvés : #GaN, #PowerElectronics, #EMobility, #DataCenters
#
# ============================================================
# 🔎 Recherche des mots clés pour : WhiteLab Genomics is a startup founded in 2019, ba...
# ✅ Mots-clés trouvés : #Genomics, #Biopharma, #AI, #GeneTherapy
#
# ============================================================
# 🔎 Recherche des mots clés pour : Work With Island designs and sells environmental f...
# ✅ Mots-clés trouvés : #EcoFriendly, #Workplace, #Soundproofing, #OfficePods
#
# ============================================================
# 🔎 Recherche des mots clés pour : Woodoo wants to change the world... of constructio...
# ✅ Mots-clés trouvés : #Biomaterial, #Sustainability, #Construction, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Xtramile is a cutting-edge AI-powered talent acqui...
# ✅ Mots-clés trouvés : #Recrutement, #IA, #Automatisation, #Analytique
#
# ============================================================
# 🔎 Recherche des mots clés pour : DeluPay actually reinvents payments from scratch. ...
# ✅ Mots-clés trouvés : #Fintech, #Paiements, #Durabilité, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Sans une description spécifique de l'entreprise, il est difficile de générer des mots-clés précis. Cependant, je peux vous fournir quelques exemples de mots-clés génériques qui sont souvent pertinents pour des entreprises technologiques ou axées sur l'
#
# ============================================================
# 🔎 Recherche des mots clés pour : Devana is a highly accessible and secure generativ...
# ✅ Mots-clés trouvés : 1. #GenAI
# 2. #SaaS
# 3. #AutoML
# 4. #KnowledgeManagement
#
# ============================================================
# 🔎 Recherche des mots clés pour : Enchanted Tools has created The Mirokaï, logistics...
# ✅ Mots-clés trouvés : #Robotics, #Logistics, #Healthcare, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Entropy provides travel demand forecasts for all o...
# ✅ Mots-clés trouvés : #Mobilité, #Prédiction, #Optimisation, #Durabilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : Epseed, established in 2023, embodies the determin...
# ✅ Mots-clés trouvés : #Cybersécurité, #BYOPC, #PME, #Dispositif
#
# ============================================================
# 🔎 Recherche des mots clés pour : EuraTechnologies is one of Europe's largest startu...
# ✅ Mots-clés trouvés : #Incubateur, #Startups, #Numérique, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Je suis désolé, mais sans une description de l'entreprise, il m'est impossible de générer des mots-clés pertinents. Pourriez-vous fournir plus d'informations sur l'entreprise, son secteur d'activité, ses technologies ou son marché cible ?
#
# ============================================================
# 🔎 Recherche des mots clés pour : Hopcast is a cutting-edge software solution that r...
# ✅ Mots-clés trouvés : #Software, #Mobile, #D2D, #DataTransfer
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Sans une description spécifique de l'entreprise, il est difficile de générer des mots-clés précis. Cependant, je peux vous fournir quelques exemples génériques qui pourraient s'appliquer à de nombreuses entreprises technologiques ou innovantes. Voici quelques suggestions :
#
# 1
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Je suis désolé, mais sans une description de l'entreprise, il m'est impossible de générer des mots-clés précis. Pourriez-vous fournir plus d'informations sur l'entreprise, comme son secteur d'activité, ses technologies ou son marché cible ?
#
# ============================================================
# 🔎 Recherche des mots clés pour : Luchrome offers the next generation ultra-low powe...
# ✅ Mots-clés trouvés : #IoT, #Display, #Flexible, #Sustainable
#
# ============================================================
# 🔎 Recherche des mots clés pour : 24/7 water quality biomonitoring with connected mo...
# ✅ Mots-clés trouvés : #Biomonitoring, #WaterQuality, #EnvironmentalTech, #PollutionControl
#
# ============================================================
# 🔎 Recherche des mots clés pour : Obo World offers innovative digital solutions base...
# ✅ Mots-clés trouvés : #IA, #Recrutement, #RessourcesHumaines, #AgentVirtuel
#
# ============================================================
# 🔎 Recherche des mots clés pour : Octavio is a French audio manufacturer dedicated t...
# ✅ Mots-clés trouvés : #Audio, #Acoustique, #Professionnel, #Atmosphère
#
# ============================================================
# 🔎 Recherche des mots clés pour : ORA presents a sophisticated design featuring a me...
# ✅ Mots-clés trouvés : #Projection, #Design, #Innovation, #Technology
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Sans une description spécifique de l'entreprise, il est difficile de générer des mots-clés précis. Cependant, je peux vous fournir des exemples de mots-clés génériques qui sont souvent utilisés pour décrire des entreprises dans le secteur technologique. Voici
#
# ============================================================
# 🔎 Recherche des mots clés pour : PLTech is a South France-based company dedicated t...
# ✅ Mots-clés trouvés : #Wearables, #Innovation, #Ergonomics, #TechR&D
#
# ============================================================
# 🔎 Recherche des mots clés pour : The Region Sud, South of France, takes part of the...
# ✅ Mots-clés trouvés : #Greentech, #Fintech, #Healtech, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ✅ Mots-clés trouvés : Sans une description spécifique de l'entreprise, il est difficile de générer des mots-clés précis. Cependant, je peux vous fournir quelques exemples généraux de mots-clés qui pourraient s'appliquer à divers secteurs technologiques et marchés :
#
# 1. #
#
# ============================================================
# 🔎 Recherche des mots clés pour : Non disponible...
# ...
# 🔎 Recherche des mots clés pour : clikOdoc is the all-in-1 platform for healthcare p...
# ✅ Mots-clés trouvés : #HealthTech, #Unicorn, #Efficiency, #Global
#
# ============================================================
# 🔎 Recherche des mots clés pour : codoc is an expert in health data, offering a heal...
# ✅ Mots-clés trouvés : #HealthData, #Healthcare, #Research, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : csky.ai solves the dilemma between AI automation a...
# ✅ Mots-clés trouvés : #IA, #Sécurité, #Confidentialité, #Automatisation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Cvnavi is a system solution company in the commerc...
# ✅ Mots-clés trouvés : #Telematics, #Automotive, #Electronics, #R&D
#
# ============================================================
# 🔎 Recherche des mots clés pour : We are the Digital Hub Initiative, originated by t...
# ✅ Mots-clés trouvés : #Innovation, #Startups, #Technologie, #Réseau
#
# ============================================================
# 🔎 Recherche des mots clés pour : deltaVision is a German deep & space tech startup ...
# ✅ Mots-clés trouvés : #Cryogenics, #SpaceTech, #Hydrogen, #Mobility
#
# ============================================================
# 🔎 Recherche des mots clés pour : deskbird is a workplace management app that puts e...
# ✅ Mots-clés trouvés : #HybridWork, #DeskBooking, #OfficeAnalytics, #EmployeeProductivity
#
# ============================================================
# 🔎 Recherche des mots clés pour : ePhantom is a breakthrough technology that address...
# ✅ Mots-clés trouvés : #5G, #mmWave, #Dosimetry, #AI
#
# ============================================================
# 🔎 Recherche des mots clés pour : eTreego not only specializes in the development of...
# ✅ Mots-clés trouvés : #GreenEnergy, #NetZero, #ChargingSolutions, #CarbonRights
#
# ============================================================
# 🔎 Recherche des mots clés pour : Operates AUBA, one of Japan's largest open innovat...
# ✅ Mots-clés trouvés : #Innovation, #Consulting, #Commercialization, #Japan
#
# ============================================================
# 🔎 Recherche des mots clés pour : Today, fleet and asset managers are faced with var...
# ✅ Mots-clés trouvés : #Electrification, #Sustainability, #Innovation, #Mobility
#
# ============================================================
# 🔎 Recherche des mots clés pour : The platform offers a range of tools to support ch...
# ✅ Mots-clés trouvés : #Comptabilité, #Durabilité, #ISO26000, #Carbone
#
# ============================================================
# 🔎 Recherche des mots clés pour : The ensogo platform, with its AI assistant, enable...
# ✅ Mots-clés trouvés : #Sustainability, #ESG, #AI, #Stakeholders
#
# ============================================================
# 🔎 Recherche des mots clés pour : evendsa is a start-up that allows you to put toget...
# ✅ Mots-clés trouvés : #Événementiel, #IA, #Automatisation, #Start-up
#
# ============================================================
# 🔎 Recherche des mots clés pour : fluiidd: Ensuring Uninterrupted Industrial Operati...
# ✅ Mots-clés trouvés : #Deeptech, #Scanner, #Efficiency, #Industrial
#
# ============================================================
# 🔎 Recherche des mots clés pour : We're one of Japan's few mobility startups, handli...
# ✅ Mots-clés trouvés : #Mobilité, #Électrique, #Innovation, #Japon
#
# ============================================================
# 🔎 Recherche des mots clés pour : The challenges of environmental education in Côte ...
# ✅ Mots-clés trouvés : #Éducation, #Durabilité, #Multilingue, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : BACK2BUZZ is the first one stop company for refurb...
# ✅ Mots-clés trouvés : #Refurbished, #Sustainability, #Electronics, #Decarbonization
#
# ============================================================
# 🔎 Recherche des mots clés pour : hub.brussels is the Brussels Agency for Business S...
# ✅ Mots-clés trouvés : #BusinessSupport, #Export, #Software, #Hospitality
#
# ============================================================
# 🔎 Recherche des mots clés pour : We are a user data api (visa for data) business th...
# ✅ Mots-clés trouvés : #DataPrivacy, #AIMonetization, #DataOwnership, #APITechnology
#
# ============================================================
# 🔎 Recherche des mots clés pour : i2Cool is a technology company incubated by the HK...
# ✅ Mots-clés trouvés : #Cooling, #EnergyEfficiency, #Sustainability, #Construction
#
# ============================================================
# 🔎 Recherche des mots clés pour : Welcome to iAVC, where we're revolutionizing emerg...
# ✅ Mots-clés trouvés : #DigitalHealth, #EmergencyCare, #Stroke, #Telemedicine
#
# ============================================================
# 🔎 Recherche des mots clés pour : iDAKTO makes digital identity easier to create, us...
# ✅ Mots-clés trouvés : #DigitalIdentity, #Cybersecurity, #GovTech, #UserExperience
#
# ============================================================
# 🔎 Recherche des mots clés pour : iPerf, a medtech start-up created in 2021, has dev...
# ✅ Mots-clés trouvés : #Medtech, #Innovation, #Cardiovascular, #ClinicalTrials
#
# ============================================================
# 🔎 Recherche des mots clés pour : ible, founded in 2015, is a wearable device compan...
# ✅ Mots-clés trouvés : #Wearable, #AirPurifier, #Innovation, #HealthTech
#
# ============================================================
# 🔎 Recherche des mots clés pour : inHEART provides an AI-based digital twin of the p...
# ✅ Mots-clés trouvés : #IA, #Cardiologie, #SantéNumérique, #JumeauNumérique
#
# ============================================================
# 🔎 Recherche des mots clés pour : info.gouv.fr informe sur les actualités gouverneme...
# ✅ Mots-clés trouvés : #Gouvernement, #Actualités, #Information, #État
#
# ============================================================
# 🔎 Recherche des mots clés pour : inoRain is providing software solutions for busine...
# ✅ Mots-clés trouvés : #OTT, #IPTV, #VOD, #SmartTV
#
# ============================================================
# 🔎 Recherche des mots clés pour : inwink is a platform for organising events and bui...
# ✅ Mots-clés trouvés : #EventTech, #CRM, #Networking, #Community
#
# ============================================================
# 🔎 Recherche des mots clés pour : Today, the means of communication are multiple and...
# ✅ Mots-clés trouvés : #Communication, #WebRTC, #Collaboration, #Encryption
#
# ============================================================
# 🔎 Recherche des mots clés pour : .lumen builds Pedestrian Autonomous Driving AI (PA...
# ✅ Mots-clés trouvés : 1. #IA
# 2. #Accessibilité
# 3. #Navigation
# 4. #Haptique
#
# ============================================================
# 🔎 Recherche des mots clés pour : The ma-cantine.agriculture.gouv.fr platform is a g...
# ✅ Mots-clés trouvés : #Catering, #Sustainability, #Organic, #FoodWaste
#
# ============================================================
# 🔎 Recherche des mots clés pour : "Transforming your ideas into success" is the cred...
# ✅ Mots-clés trouvés : #Actuators, #Sensors, #SmartMaterials, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Electric vehicle fast charging as a service with c...
# ✅ Mots-clés trouvés : #EVCharging, #RenewableEnergy, #Sustainability, #Mobility
#
# ============================================================
# 🔎 Recherche des mots clés pour : Meleap revolutionizes sports with "Hado Wow Live,"...
# ✅ Mots-clés trouvés : #AR, #Esports, #Streaming, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : monday.com is a work operating system (Work OS) wh...
# ✅ Mots-clés trouvés : #WorkOS, #Automation, #LowCode, #Collaboration
#
# ============================================================
# 🔎 Recherche des mots clés pour : Nextract energy develops SaaS software that helps ...
# ✅ Mots-clés trouvés : #SaaS, #EnergyStorage, #MachineLearning, #RenewableEnergy
#
# ============================================================
# 🔎 Recherche des mots clés pour : Deploy at Hyper-speed: Accelerate ideation, protot...
# ✅ Mots-clés trouvés : #IA, #Prototypage, #Innovation, #Lancement
#
# ============================================================
# 🔎 Recherche des mots clés pour : panthr offers personalized & supervised digital ex...
# ✅ Mots-clés trouvés : #HealthTech, #Wearable, #AI, #CancerTherapy
#
# ============================================================
# 🔎 Recherche des mots clés pour : Built on over a decade of research, pyannote AI of...
# ✅ Mots-clés trouvés : #IA, #VoiceTech, #Diarization, #API
#
# ============================================================
# 🔎 Recherche des mots clés pour : Measure, optimize and manage Product Carbon Footpr...
# ✅ Mots-clés trouvés : #Sustainability, #CarbonFootprint, #DataIntegration, #APISolutions
#
# ============================================================
# 🔎 Recherche des mots clés pour : Watches, chocolate, and… swisstech! We put the spo...
# ✅ Mots-clés trouvés : #Swisstech, #Innovation, #SportsTech, #Medtech
#
# ============================================================
# 🔎 Recherche des mots clés pour : trawa offers SMEs a solution that consists of thre...
# ✅ Mots-clés trouvés : #EnergieRenouvelable, #Logiciel, #PME, #GestionEnergie
#
# ============================================================
# 🔎 Recherche des mots clés pour : UCLOUDLINK is the world's first and leading mobile...
# ✅ Mots-clés trouvés : #Telecommunications, #Connectivity, #CloudSIM, #Marketplace
#
# ============================================================
# 🔎 Recherche des mots clés pour : uMotion is a French automobile manufacturer focuse...
# ✅ Mots-clés trouvés : #Sustainability, #UrbanMobility, #EV, #LastMile
#
# ============================================================
# 🔎 Recherche des mots clés pour : water stuff & sun is a German hydrogen start-up de...
# ✅ Mots-clés trouvés : #Hydrogen, #Renewable, #EnergyStorage, #Infrastructure
#
# ============================================================
# 🔎 Recherche des mots clés pour : we are_, located at 73 rue du Fbg Saint-Honoré in ...
# ✅ Mots-clés trouvés : #Créativité, #Networking, #Innovation, #Digital
#
# ============================================================
# 🔎 Recherche des mots clés pour : We provide customizable virtual reality speaking s...
# ✅ Mots-clés trouvés : #VR, #IA, #Éducation, #Santé
#
# ============================================================
# 🔎 Recherche des mots clés pour : xBloom, HQ'ed in California, is a leading innovato...
# ✅ Mots-clés trouvés : #CoffeeTech, #HomeBrewing, #SpecialtyCoffee, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : At the forefront of immersive experiences, xydrobe...
# ✅ Mots-clés trouvés : #Immersive, #VR, #Luxury, #Storytelling
#
# ============================================================
# 🔎 Recherche des mots clés pour : Yoona.ai is a cutting-edge AI tool that harnesses ...
# ✅ Mots-clés trouvés : #IA, #FashionTech, #Durabilité, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : zblocks revolutionizes how brands engage with cons...
# ✅ Mots-clés trouvés : #Web3, #Tokenization, #AdTech, #DataPrivacy
#
# ============================================================
# 🔎 Recherche des mots clés pour : Valorisation du patrimoine historique et culturel ...
# ✅ Mots-clés trouvés : #Tourisme, #Culture, #Patrimoine, #Réservation
#
# ============================================================
# 🔎 Recherche des mots clés pour : Premier réseau des salle de spectacle pilotées par...
# ✅ Mots-clés trouvés : #IA, #Spectacle, #Réseau, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : La plateforme avantages pour consommer moins mais ...
# ✅ Mots-clés trouvés : #Durabilité, #Économie, #Consommation, #Plateforme
#
# ============================================================
# 🔎 Recherche des mots clés pour : Pratiquez quand vous voulez, où vous voulez, avec ...
# ✅ Mots-clés trouvés : #Fitness, #Entraînement, #Flexibilité, #Coaching
#
# ============================================================
# 🔎 Recherche des mots clés pour : L'innovation au service du son naturel...
# ✅ Mots-clés trouvés : #Audio, #Acoustique, #Innovation, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : Trouvez le psy qui vous correspond...
# ✅ Mots-clés trouvés : #Santé, #Psychologie, #Plateforme, #Matching
#
# ============================================================
# 🔎 Recherche des mots clés pour : L'application qui lutte avec vous contre le mousti...
# ✅ Mots-clés trouvés : #Insecticide, #Application, #Santé, #Technologie
#
# ============================================================
# 🔎 Recherche des mots clés pour : Biometric digital ID & data storage protocol® desi...
# ✅ Mots-clés trouvés : #Biométrie, #Sécurité, #Identité, #Stockage
#
# ============================================================
# 🔎 Recherche des mots clés pour : Provider of supplementary education in france...
# ✅ Mots-clés trouvés : #Éducation, #Tutorat, #Apprentissage, #France
#
# ============================================================
# 🔎 Recherche des mots clés pour : Management consulting platform...
# ✅ Mots-clés trouvés : #Consulting, #Platform, #Business, #Strategy
#
# ============================================================
# 🔎 Recherche des mots clés pour : French international retail group and multinationa...
# ✅ Mots-clés trouvés : #Retail, #Multinational, #France, #Commerce
#
# ============================================================
# 🔎 Recherche des mots clés pour : Creating value for global companies by scaling the...
# ✅ Mots-clés trouvés : #DigitalMarketing, #International, #Strategy, #Global
#
# ============================================================
# 🔎 Recherche des mots clés pour : Consulting firm focused on digital strategy, tech ...
# ✅ Mots-clés trouvés : #Digital, #Cybersecurity, #Data, #Consulting
#
# ============================================================
# 🔎 Recherche des mots clés pour : Consulting company specializing in information tec...
# ✅ Mots-clés trouvés : #IT, #Consulting, #Tech, #Innovation
#
# ============================================================
# 🔎 Recherche des mots clés pour : We are a non-profit initiative on a mission to unl...
# ✅ Mots-clés trouvés : #DeepTech, #Innovation, #NonProfit, #Sustainability
#
# ============================================================
# 🔎 Recherche des mots clés pour : Automating pipeline generation and turning leads i...
# ✅ Mots-clés trouvés : #Automation, #LeadGeneration, #Revenue, #IntentSignals
#
# ============================================================
# 🔎 Recherche des mots clés pour : NeoLeasy, le leasing Neo & Easy...
# ✅ Mots-clés trouvés : #Leasing, #Automobile, #Fintech, #Mobilité
#
# ============================================================
# 🔎 Recherche des mots clés pour : This company appears to be a lead generation and a...
# ✅ Mots-clés trouvés : #LeadGen, #B2B, #SalesTech, #Appointments
#
# ============================================================
# 🔎 Recherche des mots clés pour : Europe's leading go-to security services provider,...
# ✅ Mots-clés trouvés : #Cybersécurité, #Sécurité, #Digital, #Entreprise
#
# ============================================================
# 🔎 Recherche des mots clés pour : Digitalization and automation of administrative an...
# ✅ Mots-clés trouvés : #Automatisation, #Comptabilité, #Digitalisation, #Logiciel
#
# ============================================================
# 🔎 Recherche des mots clés pour : Management and information systems consulting serv...
# ✅ Mots-clés trouvés : #Consulting, #Transformation, #Management, #IT
# ✅ Fichier enregistré : resul_mot_cles.csv

# %%
import streamlit as st
import pandas as pd
import openai
import os
import time
from dotenv import load_dotenv, find_dotenv

# 🔹 Charger les variables d'environnement
_ = load_dotenv(find_dotenv())

# 🔹 Configurer OpenAI
client = openai.OpenAI(api_key=os.environ.get('OPENAI_API_KEY'))

# 🔹 Fonction pour charger les données SIREN
@st.cache_data
def load_data(file_path):
    df = pd.read_csv(file_path, sep=',')  # Vérifie le séparateur
    return df

def get_keyword_from_openai(description):
    """
    Utilise l'API OpenAI pour récupérer les mots clés d'une entreprise à partir de sa description.
    """
    if pd.isna(description) or description.strip() == "":
        return "Pas de description"

    try:
        print("\n" + "=" * 60)
        print(f"🔎 Recherche des mots clés pour : {description[:50]}...")

        # 🔹 Prompt détaillé
        prompt = (
            f"À partir de la description suivante, génère **4 mots-clés** "
            "qui décrivent **le plus précisément possible** l'entreprise."
            "Les mots-clés doivent être représentatifs du secteur, de la technologie ou du marché cible."
            "Les mots clés doivent être simple en un seul mot. Pas #ContentCreation ou DigitalWorkplace qui sont 2 mots collés."
            "Utilise **des hashtags** si pertinent (ex: #3DPrinting, #IA, #Fintech)."
            "\n\n"
            f"Description : {description}\n"
            "Mots-clés :"
        )

        # 🔹 Appel à l'API OpenAI
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Tu es un expert en technologies et en analyse de marché."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=50,
            temperature=0.2
        )

        # 🔹 Extraction de la réponse
        keywords = response.choices[0].message.content.strip()

        print(f"✅ Mots-clés trouvés : {keywords}")
        return keywords

    except Exception as e:
        print(f"❌ Erreur pour la description '{description[:50]}...': {e}")
        return "Erreur"

# 🔹 Charger le fichier CSV contenant les entreprises
input_csv = "mot_cles_openai_clean.csv"  # Remplace par ton fichier source
output_csv = "resul_mot_cles.csv"

df = load_data(input_csv)

# 🔹 Vérifier si la colonne "mots_cles" existe déjà, sinon la créer
if "mots_cles" not in df.columns:
    df["mots_cles"] = None

# 🔹 Remplir les mots-clés pour les entreprises qui n'en ont pas encore
for index, row in df.iterrows():
    if pd.isna(row["mots_cles"]) or row["mots_cles"].strip() == "":
        df.at[index, "mots_cles"] = get_keyword_from_openai(row["description"])
        time.sleep(1)  # 🔹 Pause pour éviter les limitations d'OpenAI

# 🔹 Sauvegarder le fichier mis à jour
df.to_csv(output_csv, index=False)

print(f"✅ Fichier enregistré : {output_csv}")
