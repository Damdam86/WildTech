# %%
import pandas as pd
df_hub = pd.read_csv(r'sources/merged_lehub.csv')

# %%
df_hub
# Out:
#                                                    url                 name  \
# 0    https://lehub.web.bpifrance.fr/startup/beacon-...        Beacon & eggs
# 1    https://lehub.web.bpifrance.fr/startup/carfit?...               CARFIT
# 2    https://lehub.web.bpifrance.fr/startup/brennus...    BRENNUS ANALYTICS
# 3    https://lehub.web.bpifrance.fr/startup/adways?...               ADWAYS
# 4    https://lehub.web.bpifrance.fr/startup/antidot...              ANTIDOT
# ..                                                 ...                  ...
# 745  https://lehub.web.bpifrance.fr/startup/dancr?q...               DANC.R
# 746  https://lehub.web.bpifrance.fr/startup/murena-...           MURENA SAS
# 747  https://lehub.web.bpifrance.fr/startup/motion-...                  NaN
# 748  https://lehub.web.bpifrance.fr/startup/sacha?q...                SACHA
# 749  https://lehub.web.bpifrance.fr/startup/molac-l...  Molac Laurent TUITO
#
#                                                   logo  creation_year  \
# 0    https://upload.prd.hbd.cloud.bpifrance.fr/7307...         2017.0
# 1    https://upload.prd.hbd.cloud.bpifrance.fr/fedf...         2017.0
# 2    https://upload.prd.hbd.cloud.bpifrance.fr/awsS...         2016.0
# 3    https://upload.prd.hbd.cloud.bpifrance.fr/star...         2014.0
# 4    https://upload.prd.hbd.cloud.bpifrance.fr/awsS...         2007.0
# ..                                                 ...            ...
# 745  https://upload.prd.hbd.cloud.bpifrance.fr/9628...         2022.0
# 746  https://upload.prd.hbd.cloud.bpifrance.fr/bbf6...         2018.0
# 747                                                NaN            NaN
# 748  https://upload.prd.hbd.cloud.bpifrance.fr/bcb1...         2022.0
# 749  https://upload.prd.hbd.cloud.bpifrance.fr/859e...         2018.0
#
#     employees                                               tags  \
# 0       2 - 5                                                NaN
# 1     15 - 25  #Automotive, #Big Data, #Database, #Informatio...
# 2        +250                    #Computer, #Software, #Big Data
# 3    25 - 100              #Web Development, #Video, #Web Design
# 4    25 - 100                                           #antidot
# ..        ...                                                ...
# 745     2 - 5        #Sport, #Culture, #Bien être, #Entraînement
# 746  25 - 100  #privacy, #rse, #développement durable, #smart...
# 747       NaN                                                NaN
# 748     2 - 5                                     #saas, #achats
# 749    5 - 10                 #RAG, #Text2Sql, #NLU, #AI, #voice
#
#                                            description  \
# 0                        The Connected Moments Company
# 1    CARFIT révolutionne l'industrie des services a...
# 2    Brennus Analytics développe une solution d’opt...
# 3    Adways propose une solution disruptive permett...
# 4    ANTIDOT est une éditeur logiciel spécialisé da...
# ..                                                 ...
# 745  DANC.R c'est une app d'entraînement pour les p...
# 746  Murena : l'écosystème mobile à impact positif....
# 747                                                NaN
# 748  Boostez la performance de vos équipes Achats.\...
# 749  TUITO est un bureau d'étude en IA ayant dévelo...
#
#                             site  \
# 0              https://bewifi.co
# 1                 http://car.fit
# 2                            NaN
# 3         http://www.adways.com/
# 4                            NaN
# ..                           ...
# 745                          NaN
# 746           https://murena.com
# 747                          NaN
# 748  https://www.sacha.software/
# 749        https://www.tuito.fr/
#
#                                           social_links    business_model  \
# 0    [{"type": "linkedin", "url": "https://www.link...               B2B
# 1                                                   []        B2B2C, B2C
# 2                                                   []         B2B, Saas
# 3    [{"type": "linkedin", "url": "http://www.linke...               B2B
# 4                                                   []               B2B
# ..                                                 ...               ...
# 745  [{"type": "linkedin", "url": "https://www.link...               B2C
# 746  [{"type": "linkedin", "url": "https://www.link...    B2B, B2C, Saas
# 747                                                 []               NaN
# 748                                                 []               B2B
# 749                                                 []  B2B, B2B2C, Saas
#
#                          region        department       city  \
# 0                 Île-de-france      Val-de-marne   Valenton
# 1               Hauts-de-france              Nord      Lille
# 2                 Île-de-france             Paris      Paris
# 3                 Île-de-france             Paris      Paris
# 4          Auvergne-rhône-alpes             Rhône       Lyon
# ..                          ...               ...        ...
# 745               Île-de-france             Paris      Paris
# 746                   Normandie          Calvados       Caen
# 747                         NaN               NaN        NaN
# 748         Centre-val de loire    Indre-et-loire      Tours
# 749  Provence-alpes-côte d'azur  Bouches-du-rhône  La ciotat
#
#                                               presence amount_raised  \
# 0                                        France, Monde          15k€
# 1                        France, Hong-Kong, États-Unis         4,3M€
# 2                                               France        48,5M€
# 3                                               France         200k€
# 4                                   France, États-Unis         7,5M€
# ..                                                 ...           ...
# 745                                              Monde           NaN
# 746  Allemagne, Autriche, Belgique, Canada, Danemar...         2,2M€
# 747                                                NaN           NaN
# 748               Belgique, France, Luxembourg, Suisse           NaN
# 749  Allemagne, Espagne, France, Italie, Royaume-Un...           NaN
#
#      investors_count    round_max  \
# 0                0.0          BSA
# 1                5.0         Seed
# 2                7.0  ACQUISITION
# 3                4.0   Subvention
# 4                7.0     Séries A
# ..               ...          ...
# 745              NaN          NaN
# 746              2.0     Amorçage
# 747              NaN          NaN
# 748              NaN          NaN
# 749              NaN          NaN
#
#                                            investments
# 0    [{"date": "décembre 2020", "amount": "15k€", "...
# 1    [{"date": "août 2018", "amount": "2M€", "round...
# 2    [{"date": "mai 2020", "amount": "0€", "round":...
# 3    [{"date": "mars 2017", "amount": "0$", "round"...
# 4    [{"date": "janvier 2019", "amount": "5M€", "ro...
# ..                                                 ...
# 745                                                 []
# 746  [{"date": "août 2021", "amount": "1,6M$", "rou...
# 747                                                 []
# 748                                                 []
# 749                                                 []
#
# [750 rows x 18 columns]

# %%
df_mina.drop(columns=['url'], inplace=True)

# %%
df_mina = df_mina[['name', 'description', 'logo', 'infos', 'contact']]

# %%
df_mina['name'] = df_mina['name'].str.upper()

# %%
df_mina
# Out:
#                          name  \
# 0              VIAPIX SYSTEMS
# 1                     BILL UP
# 2                      U.NEAT
# 3    ECE – ECOLE D’INGÉNIEURS
# 4                      UDIMEC
# ..                        ...
# 427                 SAT4SPACE
# 428             LA NOTE BLEUE
# 429             DELTA CONCEPT
# 430   CIC LYONNAISE DE BANQUE
# 431                CNRS ALPES
#
#                                            description  \
# 0    Depuis 2004, notre équipe conçoit et développe...
# 1    Bill Up est une application conçue pour facili...
# 2    U.NEAT est une société de services numériques,...
# 3    Ecole d'ingénieurs généraliste et high-tech, l...
# 4    UDIMEC regroupe les entreprises industrielles,...
# ..                                                 ...
# 427  SAT4SPACE est une entreprise qui propose des s...
# 428  LA MAISON\nArts Vivants - Expériences Immersiv...
# 429  La société, son activité :\nPour tous ceux qui...
# 430  CIC Lyonnaise de Banque, Banque du groupe CIC,...
# 431  Le CNRS est un organisme public de recherche. ...
#
#                                                   logo  \
# 0    https://www.minalogic.com/wp-content/uploads/2...
# 1    https://www.minalogic.com/wp-content/uploads/2...
# 2    https://www.minalogic.com/wp-content/uploads/2...
# 3    https://www.minalogic.com/wp-content/uploads/2...
# 4    https://www.minalogic.com/wp-content/uploads/2...
# ..                                                 ...
# 427  https://www.minalogic.com/wp-content/uploads/2...
# 428  https://www.minalogic.com/wp-content/uploads/2...
# 429  https://www.minalogic.com/wp-content/uploads/2...
# 430  https://www.minalogic.com/wp-content/uploads/2...
# 431  https://www.minalogic.com/wp-content/uploads/2...
#
#                                                  infos  \
# 0    {"Type d'organisme": 'PME', 'Date de création'...
# 1    {"Type d'organisme": 'PME', 'Date de création'...
# 2    {"Type d'organisme": 'PME', 'Date de création'...
# 3    {"Type d'organisme": "Etablissement d'enseigne...
# 4    {"Type d'organisme": 'Organisme de développeme...
# ..                                                 ...
# 427  {"Type d'organisme": 'PME', 'Date de création'...
# 428  {"Type d'organisme": 'PME', 'Date de création'...
# 429  {"Type d'organisme": 'PME', 'Date de création'...
# 430  {"Type d'organisme": 'Banque & Investisseur', ...
# 431  {"Type d'organisme": 'Organisme de recherche',...
#
#                                                contact
# 0    {'Adresse': '1 rue Jacqueline Auriol\n        ...
# 1    {'Adresse': '386 Route de Chavanne\n          ...
# 2    {'Adresse': '41 rue de la République\n        ...
# 3    {'Adresse': "25 Rue de l'Université\n         ...
# 4    {'Adresse': '19 rue des Berges\n              ...
# ..                                                 ...
# 427  {'Adresse': 'Bât. Startway, 1 place F. Rooseve...
# 428  {'Adresse': '20 Rue de la Grenière\n          ...
# 429  {'Adresse': "1 rue de l'Isère\n               ...
# 430  {'Adresse': "8 rue du bat d'argent\n          ...
# 431  {'Adresse': '25 rue des Martyrs\n             ...
#
# [432 rows x 5 columns]
